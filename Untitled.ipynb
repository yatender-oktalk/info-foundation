# %%
import matplotlib.pyplot as plt
import pandas as pd

fig, ax = plt.subplots()

df = pd.read_csv("jobs/machine_learning_engineer.tsv", sep="\t")
# df.groupby(['Job Title']).sum().plot.bar(xlabel='Job Title', ylabel='Job counts')
# df['Job Title'].apply(lambda row: row[df['Job Title'].isin(['Machine Learning Engineer','Data Scientist'])]).df['Job Title'].value_counts().plot.bar(xlabel='Job Title', ylabel='Job counts')
# plt

# Group by 'Job Type' and count the occurrences
job_type_counts = df['Job Title'].str.lower().value_counts()

job_type_counts = job_type_counts.head(25)
job_type_counts.index = job_type_counts.index.map(str.capitalize)
print(job_type_counts)
# Plotting the bar chart
job_type_counts.plot(kind='bar', color='skyblue')

for i, (job_type, count) in enumerate(job_type_counts.items()):
    ax.text(i, count, f' {count}', ha='center', va='bottom', color='black')


plt.title('Machine Learning and Data Science Jobs Top 15')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.show()
# Out:
# Job Title
# Data scientist                                               414
# Data engineer                                                179
# Senior data scientist                                         83
# Principal engineer                                            73
# Machine learning engineer                                     70
# Python developer                                              69
# Full stack developer                                          67
# Senior data engineer                                          53
# Senior software engineer                                      45
# Senior practitioner - finance and administration delivery     43
# Practitioner - finance and administration delivery            43
# Data analyst                                                  43
# Software engineer                                             42
# Lead data scientist                                           39
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'df'
# Replace 'Experience' with the actual column name in your DataFrame
# and 'your_dataset.csv' with your dataset file or use your DataFrame directly
# df = pd.read_csv('your_dataset.csv')

# Plotting a histogram using seaborn
plt.figure(figsize=(10, 6))
sns.histplot(df['Experience'].str.extract('(\d+)-(\d+) Yrs').astype(float).mean(axis=1), bins=20, kde=True, color='skyblue')
plt.title('Distribution of Experience')
plt.xlabel('Average Experience (Years)')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'df'
# Replace 'Experience' with the actual column name in your DataFrame
# and 'your_dataset.csv' with your dataset file or use your DataFrame directly
# df = pd.read_csv('your_dataset.csv')

# Create a boxplot to visualize the distribution of experience
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Experience'].str.extract('(\d+)-(\d+) Yrs').astype(float).mean(axis=1), color='skyblue')
plt.title('Boxplot of Experience Distribution')
plt.xlabel('Average Experience (Years)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'df'
# Replace 'Experience' with the actual column name in your DataFrame
# and 'your_dataset.csv' with your dataset file or use your DataFrame directly
# df = pd.read_csv('your_dataset.csv')

# Create a violin plot to visualize the distribution of experience
plt.figure(figsize=(12, 8))
sns.violinplot(x=df['Experience'].str.extract('(\d+)-(\d+) Yrs').astype(float).mean(axis=1), color='skyblue')
plt.title('Violin Plot of Experience Distribution')
plt.xlabel('Average Experience (Years)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'df'
# Replace 'Experience' with the actual column name in your DataFrame
# and 'your_dataset.csv' with your dataset file or use your DataFrame directly
# df = pd.read_csv('your_dataset.csv')

# Extract experience ranges and create a count plot
experience_ranges = df['Experience'].str.extract('(\d+)-(\d+) Yrs').astype(float).mean(axis=1)
plt.figure(figsize=(12, 8))
sns.countplot(x=experience_ranges, color='skyblue')
plt.title('Count Plot of Experience Ranges')
plt.xlabel('Average Experience (Years)')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns

# Assuming your DataFrame is named 'df'
# Replace 'Tech Stack' with the actual column name in your DataFrame
# and 'your_dataset.csv' with your dataset file or use your DataFrame directly
# df = pd.read_csv('your_dataset.csv')

# Word Cloud for Tech Stack
tech_stack_text = ','.join(df['Tech Stack'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(tech_stack_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# plt.title('Word Cloud for Tech Stack')
plt.show()

# Count Plot for Top Technologies
top_tech_counts = df['Tech Stack'].str.split(',').explode().value_counts().nlargest(10)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_tech_counts.values, y=top_tech_counts.index, palette='viridis')
plt.title('Top 10 Technologies Used')
plt.xlabel('Count')
plt.ylabel('Technology')
plt.show()
# Out:
# /var/folders/mb/c3qzknr92jj0tb1n5172615h0000gn/T/ipykernel_79471/1433193415.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_tech_counts.values, y=top_tech_counts.index, palette='viridis')

# %%
company_counts = df['Company Name'].str.lower().value_counts()

company_counts = company_counts.head(10)
company_counts.index = company_counts.index.map(str.capitalize)
# Plotting the bar chart
company_counts.plot(kind='bar', color='skyblue')

for i, (job_type, count) in enumerate(company_counts.items()):
    ax.text(i, count, f' {count}', ha='center', va='bottom', color='black')


plt.title('Machine Learning and Data Science Jobs Top 10 companies jobs')
plt.xlabel('Company Name')
plt.ylabel('Count')
plt.show()

# %%
localtion_counts = df['Location'].str.lower().value_counts()

localtion_counts = localtion_counts.head(10)
localtion_counts.index = localtion_counts.index.map(str.capitalize)
# Plotting the bar chart
localtion_counts.plot(kind='bar', color='skyblue')
localtion_counts.index = localtion_counts.index.map(str.capitalize)

for i, (job_type, count) in enumerate(localtion_counts.items()):
    ax.text(i, count, f' {count}', ha='center', va='bottom', color='black')


plt.title('Machine Learning and Data Science Jobs Top 10 companies jobs')
plt.xlabel('Job Locations')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns

# Assuming your DataFrame is named 'df'
# Replace 'Tech Stack' with the actual column name in your DataFrame
# and 'your_dataset.csv' with your dataset file or use your DataFrame directly
# df = pd.read_csv('your_dataset.csv')

# Word Cloud for Tech Stack
tech_stack_text = ','.join(df['Tech Stack'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis',
                      max_words=200, contour_width=3, contour_color='steelblue').generate(tech_stack_text)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Tech Stack', fontsize=16, color='navy', fontweight='bold')
plt.show()

# Count Plot for Top Technologies
top_tech_counts = df['Tech Stack'].str.split(',').explode().value_counts().nlargest(10)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_tech_counts.values, y=top_tech_counts.index, palette='viridis')
plt.title('Top 10 Technologies Used', fontsize=18, color='darkgreen', fontweight='bold')
plt.xlabel('Count', fontsize=14)
plt.ylabel('Technology', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
# Out:
# /var/folders/mb/c3qzknr92jj0tb1n5172615h0000gn/T/ipykernel_79471/1901215465.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_tech_counts.values, y=top_tech_counts.index, palette='viridis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns

# Assuming your DataFrame is named 'df'
# Replace 'Tech Stack' with the actual column name in your DataFrame
# and 'your_dataset.csv' with your dataset file or use your DataFrame directly
# df = pd.read_csv('your_dataset.csv')

# Word Cloud for Tech Stack
tech_stack_text = ','.join(df['Tech Stack'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis',
                      max_words=200, contour_width=3, contour_color='steelblue').generate(tech_stack_text)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Tech Stack', fontsize=16, color='navy', fontweight='bold')
plt.show()

# Count Plot for Top Technologies
top_tech_counts = df['Tech Stack'].str.split(',').explode().value_counts().nlargest(10)

# Custom color palette
colors = sns.color_palette('mako', len(top_tech_counts))

plt.figure(figsize=(12, 8))
sns.barplot(x=top_tech_counts.values, y=top_tech_counts.index, palette=colors)
plt.title('Top 10 Technologies Used', fontsize=18, color='darkgreen', fontweight='bold')
plt.xlabel('Count', fontsize=14, color='darkblue')
plt.ylabel('Technology', fontsize=14, color='darkblue')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.show()
# Out:
# /var/folders/mb/c3qzknr92jj0tb1n5172615h0000gn/T/ipykernel_79471/1497504140.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_tech_counts.values, y=top_tech_counts.index, palette=colors)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Load data
df = pd.read_csv("jobs/machine_learning_engineer.tsv", sep="\t")

# Group by 'Job Type' and count the occurrences
job_type_counts = df['Job Title'].str.lower().value_counts().head(10)

# Capitalize the job titles for display
job_type_counts.index = job_type_counts.index.map(str.capitalize)

# Set a seaborn style for improved aesthetics
sns.set(style="whitegrid")

# Create a color palette
colors = sns.color_palette("viridis", len(job_type_counts))

# Plotting the bar chart with seaborn
plt.figure(figsize=(12, 8))
ax = sns.barplot(x=job_type_counts.values, y=job_type_counts.index, palette=colors)

# Adding data labels
for i, (job_type, count) in enumerate(job_type_counts.items()):
    ax.text(count + 0.2, i, f' {count}', va='center', color='black', fontsize=10)

plt.title('Machine Learning and Data Science Jobs Top 10', fontsize=18, color='navy', fontweight='bold')
plt.xlabel('Count', fontsize=14, color='darkblue')
plt.ylabel('Job Title', fontsize=14, color='darkblue')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
# Out:
# /var/folders/mb/c3qzknr92jj0tb1n5172615h0000gn/T/ipykernel_79471/422168416.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=job_type_counts.values, y=job_type_counts.index, palette=colors)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Load data
df = pd.read_csv("jobs/machine_learning_engineer.tsv", sep="\t")

# Group by 'Job Type' and count the occurrences
job_type_counts = df['Job Title'].str.lower().value_counts().head(5)

# Capitalize the job titles for display
job_type_counts.index = job_type_counts.index.map(str.capitalize)

# Set a seaborn style for improved aesthetics
sns.set(style="whitegrid")

# Create a color palette
colors = sns.color_palette("viridis", len(job_type_counts))

# Plotting the pie chart with matplotlib
plt.figure(figsize=(5, 4))
plt.pie(job_type_counts, labels=job_type_counts.index, autopct='%1.1f%%', colors=colors, startangle=140)

# Adding a circle at the center to make it look like a donut chart (optional)
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Top 5 Machine Learning and Data Science Job Titles', fontsize=18, color='navy', fontweight='bold')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'df'
# Replace 'Experience' with the actual column name in your DataFrame
# and 'your_dataset.csv' with your dataset file or use your DataFrame directly
# df = pd.read_csv('your_dataset.csv')

# Set a seaborn style for improved aesthetics
sns.set(style="whitegrid")

# Custom color palette
colors = sns.color_palette("muted", n_colors=2)

# Plotting a histogram using seaborn with improved styling
plt.figure(figsize=(12, 8))
sns.histplot(df, x=df['Experience'].str.extract('(\d+)-(\d+) Yrs').astype(float).mean(axis=1),
             bins=20, kde=True, hue=df['Location'], multiple="stack",
             palette=colors, edgecolor='black', linewidth=1.2)
plt.title('Distribution of Experience with Hue', fontsize=18, color='navy', fontweight='bold')
plt.xlabel('Average Experience (Years)', fontsize=14, color='darkblue')
plt.ylabel('Frequency', fontsize=14, color='darkblue')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.legend(title='SomeOtherColumn', fontsize=12)
plt.show()
# Out:
# /var/folders/mb/c3qzknr92jj0tb1n5172615h0000gn/T/ipykernel_79471/3432662909.py:18: UserWarning:
# The palette list has fewer values (2) than needed (703) and will cycle, which may produce an uninterpretable plot.
#   sns.histplot(df, x=df['Experience'].str.extract('(\d+)-(\d+) Yrs').astype(float).mean(axis=1),
# /Users/ysingh/codebase/yatender-oktalk/arizona-ml/info-foundation/env/lib/python3.11/site-packages/seaborn/distributions.py:267: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   baselines[cols] = curves[cols].shift(1, axis=1).fillna(0)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create subplots
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

# Plotting data on the first subplot (ax[0, 0])
ax[0].plot(x, y1, label='Sine')
ax[0].set_title('Subplot 1')

# Adding legend to the first subplot
ax[0].legend()

# Plotting data on the second subplot (ax[0, 1])
ax[1].plot(x, y2, label='Cosine')
ax[1].set_title('Subplot 2')

# Adding legend to the second subplot
ax[1].legend()

# Adjust layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
import seaborn as sns
df.describe()
# Out:
#        Unnamed: 0       Rating
# count  8220.00000  6383.000000
# mean   4109.50000     3.856776
# std    2373.05394     0.616233
# min       0.00000     1.000000
# 25%    2054.75000     3.600000
# 50%    4109.50000     3.900000
# 75%    6164.25000     4.200000
# max    8219.00000     5.000000

# %%
import matplotlib.pyplot as plt

# Preprocess the experience column to calculate average experience
# df['Experience_Lower'] = df['Experience'].apply(lambda x: int(x.split('-')[0]) if '-' in x else int(x.split(' ')[0]))
# df['Experience_Upper'] = df['Experience'].apply(lambda x: int(x.split('-')[1].split(' ')[0]) if '-' in x else int(x.split(' ')[0]))

# Calculate average experience
# df['Average_Experience'] = (df['Experience_Lower'] + df['Experience_Upper']) / 2
df['Average_Experience'] =df['Experience'].str.extract('(\d+)-(\d+) Yrs').astype(float).mean(axis=1)
# Set up the plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Location', y='Average_Experience', data=df, errorbar=None)

# Customize the plot
plt.title('City-wise Experience Required for Jobs')
plt.xlabel('City')
plt.ylabel('Average Experience Required (Years)')

# Rotate x-axis labels for better readability (optional)
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %%
df["is_bangalore"] = (df["Location"] == "Bengaluru")
df["is_bangalore"].describe()
sns.barplot(df["is_bangalore"])
plt.show()

# %%
sns.barplot(x=df["is_bangalore"])
plt.show()
