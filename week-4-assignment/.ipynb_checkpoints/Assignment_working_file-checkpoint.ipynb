# %% [markdown]
# # 1. Connecting to the YouTube using a python client
#
# - We enabled the API key from the google cloud console and generating the API key.
# - To connect to the youtube, we enabled only for the public data access so we don't have to deal with the oAuth related stuff as we don't need any personal data of the users.
# - After enabling the API key we would need to install the dependency via pip
#
# We used the following command to install in our virtualenv as I'm using the pip.
#
# ```
# pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# ```

# %%
import json
import csv
import pandas as pd

from pprint import pprint
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

DEVELOPER_KEY = 'AIzaSyDgc2_04BksQXvYmNgNPqCZwEvMRaZ85fI'
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'

youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)

# %% [markdown]
# # 2. Search and extract the data
# ### a) Search videos related to query string "avatar movie"
# - (For this part, choose/search one video of your choice and perform data collection steps on that specific video )
#
#
# We will only create the collection for the video as we don't really care about the playlist and channel now,
# notherwise that can also be done via fetching the particular `type`

# %%
def youtube_search(search_query, max_results):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)

    # Call the search.list method to retrieve results matching the specified
    # query term.
    search_response = youtube.search().list(
    q=search_query,
    part='id,snippet',
    type="video",
    maxResults=max_results
    ).execute()

    videos = []

    # Add each result to the appropriate list, and then display the lists of
    for search_result in search_response.get('items', []):
        if search_result['id']['kind'] == 'youtube#video':
          videos.append(search_result)

    return videos

def extract_data(video_data):
    #  Preparing the simple dictionary for Channel ID, Video Description, Channel Title, Video Title
    video_snippet = video_data["snippet"]
    data = {
            "channel ID": video_snippet['channelId'],
            "video Description": video_snippet['description'],
            "Channel Title": video_snippet['channelTitle'],
            "Video Title": video_snippet['title']
           }
    print("\n")
    for key in data:
        print(key, "-> ", data[key], "\n")

# We will fetch only 5 results
videos = youtube_search("avatar movie", 5)
extract_data(videos[0])
# Out:
# channel ID ->  UC0A86RKLCqTEUna3hPlEpzg
#
# video Description ->  AVATAR Full Movie 2023: Fallen Kingdom | Superhero FXL Action Movies 2023 in English (Game Movie). Best Action Game ...
#
# Channel Title ->  Superhero FXL Games
#
# Video Title ->  AVATAR Full Movie 2023: Fallen Kingdom | Superhero FXL Action Movies 2023 in English (Game Movie)

# %% [markdown]
# ### 2.b  Provide the following statistics for query string “avatar movie” of top 50 videos sorted by relevance in the US region.
#
# > Output expected: video ID, title, no of views, no of likes,no of comments exported to CSV file

# %%
def youtube_search_with_region(search_query, max_results, region_code):
    search_response = youtube.search().list(
        q=search_query,
        part='id,snippet',
        type="video",
        regionCode=region_code,
        maxResults=max_results
    ).execute()
    
    videos = []

    # Add each result to the appropriate list, and then display the lists of
    for search_result in search_response.get('items', []):
        if search_result['id']['kind'] == 'youtube#video':
          videos.append(search_result)

    return videos

def video_id_list(video_list):
    video_id_list = []
    for video in video_list:
        video_id_list.append(video['id']['videoId'])
    return video_id_list


def write_csv_file(data, file_name):
    df = pd.DataFrame(video_data)
    df.to_csv(file_name)


def extract_video_information(video):
#     video ID, title, no of views, no of likes,no of comments
    statistics = video['statistics']
    print(statistics)
    content = video['contentDetails']
    video_id = video['id']
    return {
        "video_id": video_id, 
        "no_of_likes": statistics.get('likeCount', 0),
        "no_of_views": statistics.get('viewCount', 0),
        "title": video['snippet']['title'],
        "no_of_comments": statistics.get('commentCount', 0)
    }
    
        
def video_information(video_ids):
    search_response = youtube.videos().list(
        part='id,snippet,statistics,contentDetails',
        id=video_ids
    ).execute()
    
    videos = []
    for search_result in search_response.get('items', []):
        if search_result['kind'] == 'youtube#video':
          videos.append(extract_video_information(search_result))
        
    return videos

videos = youtube_search_with_region("avatar movie", 50, "US")
video_id_list = video_id_list(videos)
video_data = video_information(video_id_list)
write_csv_file(video_data, "./2b-data.csv")
# Out:
# {'viewCount': '2422461', 'likeCount': '18583', 'favoriteCount': '0', 'commentCount': '479'}
# {'viewCount': '58123548', 'likeCount': '1042782', 'favoriteCount': '0', 'commentCount': '43090'}
# {'viewCount': '13673995', 'likeCount': '338836', 'favoriteCount': '0', 'commentCount': '31472'}
# {'viewCount': '475907', 'likeCount': '3761', 'favoriteCount': '0', 'commentCount': '612'}
# {'viewCount': '12790401', 'likeCount': '81208', 'favoriteCount': '0', 'commentCount': '8939'}
# {'viewCount': '218736', 'likeCount': '2872', 'favoriteCount': '0', 'commentCount': '64'}
# {'viewCount': '827420', 'likeCount': '7016', 'favoriteCount': '0', 'commentCount': '424'}
# {'viewCount': '1178087', 'likeCount': '4339', 'favoriteCount': '0', 'commentCount': '123'}
# {'viewCount': '506553', 'likeCount': '5013', 'favoriteCount': '0', 'commentCount': '209'}
# {'viewCount': '27757967', 'likeCount': '682437', 'favoriteCount': '0', 'commentCount': '29018'}
# {'viewCount': '12023943', 'likeCount': '78511', 'favoriteCount': '0', 'commentCount': '1688'}
# {'viewCount': '3187605', 'likeCount': '39160', 'favoriteCount': '0', 'commentCount': '1422'}
# {'viewCount': '42620122', 'likeCount': '201546', 'favoriteCount': '0', 'commentCount': '1314'}
# {'viewCount': '1287733', 'likeCount': '16844', 'favoriteCount': '0', 'commentCount': '862'}
# {'viewCount': '2336040', 'likeCount': '18035', 'favoriteCount': '0', 'commentCount': '635'}
# {'viewCount': '5354168', 'likeCount': '23130', 'favoriteCount': '0', 'commentCount': '674'}
# {'viewCount': '28525140', 'likeCount': '163668', 'favoriteCount': '0', 'commentCount': '2209'}
# {'viewCount': '289160', 'likeCount': '3671', 'favoriteCount': '0', 'commentCount': '170'}
# {'viewCount': '579243', 'likeCount': '8996', 'favoriteCount': '0', 'commentCount': '322'}
# {'viewCount': '2532311', 'likeCount': '49529', 'favoriteCount': '0', 'commentCount': '1667'}
# {'viewCount': '32308503', 'likeCount': '191742', 'favoriteCount': '0', 'commentCount': '3675'}
# {'viewCount': '609640', 'likeCount': '10338', 'favoriteCount': '0', 'commentCount': '318'}
# {'viewCount': '572531', 'likeCount': '4866', 'favoriteCount': '0', 'commentCount': '199'}
# {'viewCount': '2916675', 'likeCount': '8125', 'favoriteCount': '0', 'commentCount': '134'}
# {'viewCount': '61079', 'likeCount': '232', 'favoriteCount': '0', 'commentCount': '12'}
# {'viewCount': '7718732', 'likeCount': '350308', 'favoriteCount': '0', 'commentCount': '3997'}
# {'viewCount': '13117562', 'likeCount': '54037', 'favoriteCount': '0', 'commentCount': '754'}
# {'viewCount': '1830018', 'likeCount': '21218', 'favoriteCount': '0', 'commentCount': '593'}
# {'viewCount': '148851256', 'likeCount': '1152900', 'favoriteCount': '0', 'commentCount': '3280'}
# {'viewCount': '367331', 'likeCount': '32595', 'favoriteCount': '0', 'commentCount': '1204'}
# {'viewCount': '858187', 'likeCount': '60803', 'favoriteCount': '0', 'commentCount': '277'}
# {'viewCount': '2115224', 'likeCount': '10632', 'favoriteCount': '0', 'commentCount': '137'}
# {'viewCount': '3256048', 'likeCount': '55194', 'favoriteCount': '0', 'commentCount': '3976'}
# {'viewCount': '10146503', 'likeCount': '78342', 'favoriteCount': '0', 'commentCount': '0'}
# {'viewCount': '785840', 'likeCount': '6153', 'favoriteCount': '0', 'commentCount': '1082'}
# {'viewCount': '430445', 'likeCount': '25921', 'favoriteCount': '0', 'commentCount': '4044'}
# {'viewCount': '2267431', 'likeCount': '187296', 'favoriteCount': '0', 'commentCount': '4628'}
# {'viewCount': '35339', 'likeCount': '3304', 'favoriteCount': '0', 'commentCount': '693'}
# {'viewCount': '2395060', 'likeCount': '18384', 'favoriteCount': '0', 'commentCount': '745'}
# {'viewCount': '24091558', 'likeCount': '1021146', 'favoriteCount': '0', 'commentCount': '3184'}
# {'viewCount': '2216434', 'likeCount': '135035', 'favoriteCount': '0', 'commentCount': '5399'}
# {'viewCount': '267409', 'likeCount': '16484', 'favoriteCount': '0', 'commentCount': '215'}
# {'viewCount': '5117873', 'likeCount': '154752', 'favoriteCount': '0', 'commentCount': '27173'}
# {'viewCount': '3528043', 'likeCount': '31382', 'favoriteCount': '0', 'commentCount': '799'}
# {'viewCount': '2184984', 'likeCount': '7334', 'favoriteCount': '0', 'commentCount': '60'}
# {'viewCount': '287884', 'likeCount': '1891', 'favoriteCount': '0', 'commentCount': '188'}
# {'viewCount': '3204292', 'likeCount': '27280', 'favoriteCount': '0', 'commentCount': '641'}
# {'viewCount': '1487201', 'likeCount': '4393', 'favoriteCount': '0', 'commentCount': '51'}
# {'viewCount': '16184991', 'likeCount': '120691', 'favoriteCount': '0', 'commentCount': '1631'}
# {'likeCount': '20852', 'favoriteCount': '0', 'commentCount': '1691'}

# %% [markdown]
# # 3. Analyze the exported data obtained in 2.b and carry out the following tasks
#
# ### a) Sort the data 2.b by top 10 comments in descending order and consider the video IDs and Titles of top 10 videos which have highest comments.

# %%
# Create the dataframe
df = pd.DataFrame(video_data)
df['no_of_comments']= df.no_of_comments.astype(int)

df_sorted = df.sort_values(by='no_of_comments', ascending=False)
top_10_sorted = df_sorted.head(10)

# As it's not mentioned the no_of_comments in the description but still writing as 
# it's easy to check the number of comments
data = top_10_sorted.loc[:, ["video_id", "title", "no_of_comments"]]

pprint(data)
# Out:
#        video_id                                              title  \
# 1   d9MyW72ELq0        Avatar: The Way of Water | Official Trailer
# 2   waJKJW_XU90  Avatar: The Last Airbender | Official Teaser |...
# 9   a8Gx8wiNbs8  Avatar: The Way of Water | Official Teaser Tra...
# 42  2r71I8lvTIA  The Last Airbender Film: How it Disrespected a...
# 4   5PSNL1qE6VY  Avatar | Official Trailer (HD) | 20th Century FOX
# 40  p_GgAHd5siE                           TOPH: An Avatar Fan Film
# 36  T5vdPy7nbRQ                         Avatar Element Animation 2
# 35  RGx8rYbRVR4  Why People Hate Avatar: A Lesson In Lazy Comme...
# 25  f5Zx8iPek5I  Avatar 3 Will Introduce The Dark Side🔥 Of Na'v...
# 32  QOg9LUIvaig  AVATAR: THE LAST AIRBENDER | Water, Earth, Fir...
#
#     no_of_comments
# 1            43090
# 2            31472
# 9            29018
# 42           27173
# 4             8939
# 40            5399
# 36            4628
# 35            4044
# 25            3997
# 32            3976

# %% [markdown]
# ### b). Use a suitable method to retrieve comments of those top 10 videos from 3.a.
# > For doing this, write a program to loop through each video id from 3.a and pass in the part parameter set to "snippet", to retrieve basic details about the comments. Execute this request and print the response using the pprint() method.
#
# #### Note: I am not fetching all the comments in the video, only the first level of default comments just to show that we can do more

# %%
# Call the API's commentThreads.list method to list the existing comments.

def get_comments(video_id):
    results = youtube.commentThreads().list(
    part="snippet",
    videoId=video_id,
    textFormat="plainText"
    ).execute()

    pprint(results)

def print_video_comments(video_list):
    for video_id in video_list:
        get_comments(video_id)
        
print_video_comments(data["video_id"])
# Out:
# {'etag': 'Go5Y5VHkymTBjI0EH5Z3CVygN2g',
#  'items': [{'etag': 'XsCS-xW3bre2AtAidI5ZudN6cAc',
#             'id': 'Ugy9R8bfFFOJbZWLMY54AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'IUN4pJhnNNF0jPN74vd4UK0NmLg',
#                                             'id': 'Ugy9R8bfFFOJbZWLMY54AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCvLUhqiJ307WlvVbZSPzlEQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCvLUhqiJ307WlvVbZSPzlEQ',
#                                                         'authorDisplayName': 'IT '
#                                                                              'Ian',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKZbEV3u9hGjRfMV1MlkCPJrCP69S81MxiO7RQ=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2023-11-14T05:48:58Z',
#                                                         'textDisplay': 'Damn '
#                                                                        'that '
#                                                                        'background '
#                                                                        'scores '
#                                                                        'hit 😳',
#                                                         'textOriginal': 'Damn '
#                                                                         'that '
#                                                                         'background '
#                                                                         'scores '
#                                                                         'hit 😳',
#                                                         'updatedAt': '2023-11-14T05:48:58Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'bkmV9Tisb-1OzAB3453DY4jwF30',
#             'id': 'UgxJQ2TO0o1yAwQJv_Z4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'PvGJg4jfKBcBoDCq5Z1N7eotQiA',
#                                             'id': 'UgxJQ2TO0o1yAwQJv_Z4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCuuoaCMslKf7YwjYbSZIpfg'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCuuoaCMslKf7YwjYbSZIpfg',
#                                                         'authorDisplayName': 'Zia '
#                                                                              'Ur '
#                                                                              'Rehman',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/IoALH8xKZwoUloYsJPbHlrCNmzT1yYq5HR9yg3B_FU7AcuqpeM_P3NI_F6Fqriv6Lvu45yMN=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 1,
#                                                         'publishedAt': '2023-11-12T16:44:55Z',
#                                                         'textDisplay': 'Teaser '
#                                                                        'is '
#                                                                        'better '
#                                                                        'than '
#                                                                        'trailer '
#                                                                        'i '
#                                                                        'think❤',
#                                                         'textOriginal': 'Teaser '
#                                                                         'is '
#                                                                         'better '
#                                                                         'than '
#                                                                         'trailer '
#                                                                         'i '
#                                                                         'think❤',
#                                                         'updatedAt': '2023-11-12T16:44:55Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'c2Qs5JrzYoPL8jB5f2RMObmWVCk',
#             'id': 'UgznsmdN7aCoc2mEJdN4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'vfZ2nxMgVVg3eCTu9mM45-_TbDs',
#                                             'id': 'UgznsmdN7aCoc2mEJdN4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UC5GZOrc8XO6x9A8n5Eil9Hg'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UC5GZOrc8XO6x9A8n5Eil9Hg',
#                                                         'authorDisplayName': 'Flat '
#                                                                              'Line',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKZ0ddNaCXdkMEMn6hTnt2lSAxTkmCbQXdNPSRGL=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 1,
#                                                         'publishedAt': '2023-11-09T03:53:25Z',
#                                                         'textDisplay': 'Everyone '
#                                                                        'that '
#                                                                        'must '
#                                                                        'have '
#                                                                        'liked '
#                                                                        'this '
#                                                                        'movie '
#                                                                        'must '
#                                                                        'be a '
#                                                                        'bad '
#                                                                        'parent '
#                                                                        'and '
#                                                                        'has a '
#                                                                        'zero '
#                                                                        'observational. '
#                                                                        'Or is '
#                                                                        'filthy '
#                                                                        'Rich '
#                                                                        "that's "
#                                                                        'a bad '
#                                                                        'parent '
#                                                                        'that '
#                                                                        'has '
#                                                                        'zero '
#                                                                        'observational '
#                                                                        'skills '
#                                                                        'and '
#                                                                        "it's "
#                                                                        'pretty '
#                                                                        'damn '
#                                                                        'stupid '
#                                                                        'too. '
#                                                                        "It's "
#                                                                        'like '
#                                                                        'saying '
#                                                                        'the '
#                                                                        'last '
#                                                                        'Expendables '
#                                                                        'was '
#                                                                        'good. '
#                                                                        'Yeah '
#                                                                        "let's "
#                                                                        'just '
#                                                                        'show '
#                                                                        'people '
#                                                                        'how to '
#                                                                        'use '
#                                                                        'brass '
#                                                                        'knuckles '
#                                                                        'in a '
#                                                                        'fight. '
#                                                                        'Brass '
#                                                                        'knuckles '
#                                                                        'are '
#                                                                        'for '
#                                                                        'pussy!',
#                                                         'textOriginal': 'Everyone '
#                                                                         'that '
#                                                                         'must '
#                                                                         'have '
#                                                                         'liked '
#                                                                         'this '
#                                                                         'movie '
#                                                                         'must '
#                                                                         'be a '
#                                                                         'bad '
#                                                                         'parent '
#                                                                         'and '
#                                                                         'has a '
#                                                                         'zero '
#                                                                         'observational. '
#                                                                         'Or is '
#                                                                         'filthy '
#                                                                         'Rich '
#                                                                         "that's "
#                                                                         'a bad '
#                                                                         'parent '
#                                                                         'that '
#                                                                         'has '
#                                                                         'zero '
#                                                                         'observational '
#                                                                         'skills '
#                                                                         'and '
#                                                                         "it's "
#                                                                         'pretty '
#                                                                         'damn '
#                                                                         'stupid '
#                                                                         'too. '
#                                                                         "It's "
#                                                                         'like '
#                                                                         'saying '
#                                                                         'the '
#                                                                         'last '
#                                                                         'Expendables '
#                                                                         'was '
#                                                                         'good. '
#                                                                         'Yeah '
#                                                                         "let's "
#                                                                         'just '
#                                                                         'show '
#                                                                         'people '
#                                                                         'how '
#                                                                         'to '
#                                                                         'use '
#                                                                         'brass '
#                                                                         'knuckles '
#                                                                         'in a '
#                                                                         'fight. '
#                                                                         'Brass '
#                                                                         'knuckles '
#                                                                         'are '
#                                                                         'for '
#                                                                         'pussy!',
#                                                         'updatedAt': '2023-11-09T03:53:25Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'GwCpCK39315mP7WasQM-xJyLwvY',
#             'id': 'UgyNmgWIx8JHWanDlF54AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'VU9kq7xmUYdPu23Xx45hzu3OSb8',
#                                             'id': 'UgyNmgWIx8JHWanDlF54AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UC-tmQ8nLToQncbsNRMMS69w'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UC-tmQ8nLToQncbsNRMMS69w',
#                                                         'authorDisplayName': 'Berlinzzezy',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/HlIKSmvl69KArg06HJp9k6w5PYvIAnvOCfhQQTKHPQRLxHzl8xjBwS2UJfYpBVoa8ONw1i6cUw=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 3,
#                                                         'publishedAt': '2023-11-05T18:26:06Z',
#                                                         'textDisplay': 'Wow '
#                                                                        'it’s '
#                                                                        'been a '
#                                                                        'year '
#                                                                        'still '
#                                                                        'love '
#                                                                        'this '
#                                                                        'movie!!',
#                                                         'textOriginal': 'Wow '
#                                                                         'it’s '
#                                                                         'been '
#                                                                         'a '
#                                                                         'year '
#                                                                         'still '
#                                                                         'love '
#                                                                         'this '
#                                                                         'movie!!',
#                                                         'updatedAt': '2023-11-05T18:26:06Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'w7yDJh6a4uE0xpCzyD8JmPs2jhc',
#             'id': 'Ugwi9xmqkTK_MgptstR4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'JwZEbTArqUEIPzd_LhJU-_6UmxE',
#                                             'id': 'Ugwi9xmqkTK_MgptstR4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UC-srit-mFTvkmDYD0cUgqRw'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UC-srit-mFTvkmDYD0cUgqRw',
#                                                         'authorDisplayName': 'Michael '
#                                                                              'Gardin '
#                                                                              'JR',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKZwuFALNloKTr98bxu5qng86_I2heuso9bdJsGOZBgFH_kqnhqJ4EnuB4uZWJ_i=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 4,
#                                                         'publishedAt': '2023-11-02T17:00:27Z',
#                                                         'textDisplay': 'I Know '
#                                                                        'It’s '
#                                                                        'Been A '
#                                                                        'Year, '
#                                                                        'But '
#                                                                        'Why Do '
#                                                                        'I Feel '
#                                                                        'Nostalgic '
#                                                                        'Watching '
#                                                                        'This?',
#                                                         'textOriginal': 'I '
#                                                                         'Know '
#                                                                         'It’s '
#                                                                         'Been '
#                                                                         'A '
#                                                                         'Year, '
#                                                                         'But '
#                                                                         'Why '
#                                                                         'Do I '
#                                                                         'Feel '
#                                                                         'Nostalgic '
#                                                                         'Watching '
#                                                                         'This?',
#                                                         'updatedAt': '2023-11-02T17:00:27Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 1,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'Be9OnP9kAAd2VoOH4F72I41wYr8',
#             'id': 'Ugy3C7msAhQAjj5Qnm14AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'YQ55ylbEGzIOLMRLUOdCkmvgnE4',
#                                             'id': 'Ugy3C7msAhQAjj5Qnm14AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCzBcyYPLr7Qh4EMCS5sRaLg'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCzBcyYPLr7Qh4EMCS5sRaLg',
#                                                         'authorDisplayName': 'Alessandro '
#                                                                              'Leoni '
#                                                                              '- '
#                                                                              'Spaghetti2003',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/eF-wOMbTrB6emIncSyw2ddk1D-29vo2ZapA42eQ3L7ZIHxS6zLg8v4DdH3rmBITiQXDf8yxEEQ=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 3,
#                                                         'publishedAt': '2023-11-02T14:13:59Z',
#                                                         'textDisplay': 'today '
#                                                                        'this '
#                                                                        'trailer '
#                                                                        'is 1 '
#                                                                        'year '
#                                                                        'old',
#                                                         'textOriginal': 'today '
#                                                                         'this '
#                                                                         'trailer '
#                                                                         'is 1 '
#                                                                         'year '
#                                                                         'old',
#                                                         'updatedAt': '2023-11-02T14:13:59Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': '88ewV0zh5LfxL5KMF6HaNHERDtc',
#             'id': 'Ugx89J02VZDY-yzwh454AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '_FrwlA6mTc4lZRQ5iXXe0xyVc3Q',
#                                             'id': 'Ugx89J02VZDY-yzwh454AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCxOUX5G2kiCnsu7Qbgjdk3Q'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCxOUX5G2kiCnsu7Qbgjdk3Q',
#                                                         'authorDisplayName': 'GTV',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/3aTATV-cA_JphWgRjGGzMV7TjQbK_PvXx-yHEMXSJJHbO2tz6J-sKB3EMsouJCscx0dx1p7mAA=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 2,
#                                                         'publishedAt': '2023-11-02T13:12:17Z',
#                                                         'textDisplay': "It's "
#                                                                        'been a '
#                                                                        'year. '
#                                                                        'Happy '
#                                                                        'anniversary, '
#                                                                        'Avatar '
#                                                                        '2!',
#                                                         'textOriginal': "It's "
#                                                                         'been '
#                                                                         'a '
#                                                                         'year. '
#                                                                         'Happy '
#                                                                         'anniversary, '
#                                                                         'Avatar '
#                                                                         '2!',
#                                                         'updatedAt': '2023-11-02T13:12:17Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'sOaHHJdhQmyojWzEDC_N0kilv4c',
#             'id': 'UgwNDfb3LVn-VGkX1Dh4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'EJhDayM0bZztmDvn0Ehz5SFbKVM',
#                                             'id': 'UgwNDfb3LVn-VGkX1Dh4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCORLH3kHlj1IbCusEITZUFA'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCORLH3kHlj1IbCusEITZUFA',
#                                                         'authorDisplayName': 'Galactic '
#                                                                              'Hyena',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/esOKMsA9LlwZeFviDh4Baxv6iOMG5-GGfbrlipvuycwrpsQCkTRRrQQJkBc8e1V_H_LqRfn5Y4Y=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 4,
#                                                         'publishedAt': '2023-11-02T12:18:59Z',
#                                                         'textDisplay': "It's "
#                                                                        'been '
#                                                                        'one '
#                                                                        'year. '
#                                                                        'Time '
#                                                                        'is '
#                                                                        'fast!',
#                                                         'textOriginal': "It's "
#                                                                         'been '
#                                                                         'one '
#                                                                         'year. '
#                                                                         'Time '
#                                                                         'is '
#                                                                         'fast!',
#                                                         'updatedAt': '2023-11-02T12:18:59Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 1,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': '9_Imj4j0TXB21ALxi1RMdfMh_zk',
#             'id': 'UgzI-bHjQ9yUsY00qxx4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'TrrpIqS_MJs17Rt_tmwfs_mIOK4',
#                                             'id': 'UgzI-bHjQ9yUsY00qxx4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCTr9fQH14vRSAeG4D5bz7mA'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCTr9fQH14vRSAeG4D5bz7mA',
#                                                         'authorDisplayName': 'LEO🦁',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/-EAkCcWH9L_okfO0i_Ax3uVogHYDLkexHUHtv5iiUtNwUOnTaAhWl_2o7wCo7oddu_JH3cpbag=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2023-10-31T10:07:31Z',
#                                                         'textDisplay': '',
#                                                         'textOriginal': '',
#                                                         'updatedAt': '2023-10-31T10:07:31Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'eFrIluXJ9VB6lD8QH4ShWoXkTjA',
#             'id': 'Ugxzts79CO4bGcNdH7t4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'ngTklOnecVh7SwIOjyN9hIs_01Y',
#                                             'id': 'Ugxzts79CO4bGcNdH7t4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCjKgsrVx41sSTs_s9V03hHw'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCjKgsrVx41sSTs_s9V03hHw',
#                                                         'authorDisplayName': 'Ethan '
#                                                                              'Harket',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKaVefB2zkLfGuf-AQnQnrRk7ZqTU2pFM5Sp6ZCV=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2023-10-30T23:43:35Z',
#                                                         'textDisplay': 'No '
#                                                                        'idea '
#                                                                        'how a '
#                                                                        'race '
#                                                                        'so '
#                                                                        'Primitve '
#                                                                        'and '
#                                                                        'peaceful '
#                                                                        'can '
#                                                                        'beat '
#                                                                        'an '
#                                                                        'advanced '
#                                                                        'warlike '
#                                                                        'species '
#                                                                        'like '
#                                                                        'us.The '
#                                                                        'tech '
#                                                                        'looks '
#                                                                        'too '
#                                                                        'much '
#                                                                        'like '
#                                                                        'halo. '
#                                                                        "I'm "
#                                                                        'Suprised '
#                                                                        'Master '
#                                                                        'Chief '
#                                                                        "didn't "
#                                                                        'show '
#                                                                        'up and '
#                                                                        'mop '
#                                                                        'the '
#                                                                        'whole '
#                                                                        'damn '
#                                                                        'planet '
#                                                                        '.Sequel: '
#                                                                        'Humans '
#                                                                        'return '
#                                                                        'and '
#                                                                        'wipe '
#                                                                        'out '
#                                                                        'the '
#                                                                        'blue '
#                                                                        'heathen '
#                                                                        'treehuggers. '
#                                                                        'Later '
#                                                                        'in '
#                                                                        'history '
#                                                                        'books: '
#                                                                        '"It '
#                                                                        'turned '
#                                                                        'out '
#                                                                        'that '
#                                                                        'their '
#                                                                        'spears '
#                                                                        'were '
#                                                                        'no '
#                                                                        'match '
#                                                                        'for '
#                                                                        'our '
#                                                                        'nukes." '
#                                                                        'I '
#                                                                        'never '
#                                                                        'understood '
#                                                                        'why it '
#                                                                        'was '
#                                                                        'they '
#                                                                        'thought '
#                                                                        'that '
#                                                                        'humanity '
#                                                                        'would '
#                                                                        'just '
#                                                                        'count '
#                                                                        'their '
#                                                                        'losses '
#                                                                        'and '
#                                                                        'leave '
#                                                                        'Pandora '
#                                                                        'alone. '
#                                                                        'If '
#                                                                        'they '
#                                                                        'really '
#                                                                        'wanted '
#                                                                        'that  '
#                                                                        'Unoptanium '
#                                                                        'or '
#                                                                        'whatever '
#                                                                        'it was '
#                                                                        'called, '
#                                                                        'surely '
#                                                                        "they'd "
#                                                                        'send a '
#                                                                        'proper '
#                                                                        'military '
#                                                                        'force '
#                                                                        'next '
#                                                                        'time. '
#                                                                        'When '
#                                                                        'the '
#                                                                        'East '
#                                                                        'India '
#                                                                        'Company '
#                                                                        'failed '
#                                                                        'to '
#                                                                        'secure '
#                                                                        'India, '
#                                                                        'Great '
#                                                                        'Britain '
#                                                                        'annexed '
#                                                                        'it and '
#                                                                        'put it '
#                                                                        'under '
#                                                                        'martial '
#                                                                        'law. A '
#                                                                        'private '
#                                                                        'company '
#                                                                        'nearly '
#                                                                        'wiped '
#                                                                        'out '
#                                                                        'the '
#                                                                        "Na'vi, "
#                                                                        "what's "
#                                                                        'to '
#                                                                        'stop a '
#                                                                        'full '
#                                                                        'military '
#                                                                        'invasion? '
#                                                                        'Just '
#                                                                        'seemed '
#                                                                        'like a '
#                                                                        'bit of '
#                                                                        'a plot '
#                                                                        'hole '
#                                                                        'to me.',
#                                                         'textOriginal': 'No '
#                                                                         'idea '
#                                                                         'how a '
#                                                                         'race '
#                                                                         'so '
#                                                                         'Primitve '
#                                                                         'and '
#                                                                         'peaceful '
#                                                                         'can '
#                                                                         'beat '
#                                                                         'an '
#                                                                         'advanced '
#                                                                         'warlike '
#                                                                         'species '
#                                                                         'like '
#                                                                         'us.The '
#                                                                         'tech '
#                                                                         'looks '
# ...
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKY2xQBKqBidu_NgJbBCBqBkv5oV6ebK-0WkvA=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCWOA1ZGywLbqmigxE4Qlvuw',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2023-11-09T01:59:50Z',
#                                                         'textDisplay': 'Considering '
#                                                                        'how '
#                                                                        'bad '
#                                                                        'the '
#                                                                        'movie '
#                                                                        'was '
#                                                                        'Netflix '
#                                                                        'has '
#                                                                        'only '
#                                                                        'to do '
#                                                                        'the '
#                                                                        'absolute '
#                                                                        'bare '
#                                                                        'minimum '
#                                                                        'to be '
#                                                                        'already '
#                                                                        'better.',
#                                                         'textOriginal': 'Considering '
#                                                                         'how '
#                                                                         'bad '
#                                                                         'the '
#                                                                         'movie '
#                                                                         'was '
#                                                                         'Netflix '
#                                                                         'has '
#                                                                         'only '
#                                                                         'to do '
#                                                                         'the '
#                                                                         'absolute '
#                                                                         'bare '
#                                                                         'minimum '
#                                                                         'to be '
#                                                                         'already '
#                                                                         'better.',
#                                                         'updatedAt': '2023-11-09T01:59:50Z',
#                                                         'videoId': 'QOg9LUIvaig',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'QOg9LUIvaig'}},
#            {'etag': 'DLYGcZiWGV_KNme1ZdGpzsBCG0o',
#             'id': 'UgzDZGih2SKU8hWhTHd4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCWOA1ZGywLbqmigxE4Qlvuw',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'vfugzzRfnYZtcTtaulMVdAmpNjw',
#                                             'id': 'UgzDZGih2SKU8hWhTHd4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCewmvwLsUjchD-Nw-Xe99IA'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCewmvwLsUjchD-Nw-Xe99IA',
#                                                         'authorDisplayName': 'Devan '
#                                                                              'Moran',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKa5k-nUhTcKLZQXoZuKiSUeIttgK8BCOUcw1Q=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCWOA1ZGywLbqmigxE4Qlvuw',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2023-11-08T21:04:44Z',
#                                                         'textDisplay': "It's "
#                                                                        'going '
#                                                                        'to be '
#                                                                        'good',
#                                                         'textOriginal': "It's "
#                                                                         'going '
#                                                                         'to be '
#                                                                         'good',
#                                                         'updatedAt': '2023-11-08T21:04:44Z',
#                                                         'videoId': 'QOg9LUIvaig',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'QOg9LUIvaig'}},
#            {'etag': 'kN3jwGDmShauQ6E3EwSMOdVCDxw',
#             'id': 'Ugzb3S7zHxpo1JbPgXt4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCWOA1ZGywLbqmigxE4Qlvuw',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '7vQi76dpjAW4bMIPq_uLuJeYxPI',
#                                             'id': 'Ugzb3S7zHxpo1JbPgXt4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCewmvwLsUjchD-Nw-Xe99IA'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCewmvwLsUjchD-Nw-Xe99IA',
#                                                         'authorDisplayName': 'Devan '
#                                                                              'Moran',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKa5k-nUhTcKLZQXoZuKiSUeIttgK8BCOUcw1Q=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCWOA1ZGywLbqmigxE4Qlvuw',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2023-11-08T21:04:06Z',
#                                                         'textDisplay': 'When '
#                                                                        'is the '
#                                                                        'trailer '
#                                                                        'coming '
#                                                                        'out?',
#                                                         'textOriginal': 'When '
#                                                                         'is '
#                                                                         'the '
#                                                                         'trailer '
#                                                                         'coming '
#                                                                         'out?',
#                                                         'updatedAt': '2023-11-08T21:04:06Z',
#                                                         'videoId': 'QOg9LUIvaig',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 1,
#                         'videoId': 'QOg9LUIvaig'}},
#            {'etag': '5VMQVTJ_AB9yil_vdH7M7tGNDHI',
#             'id': 'UgxvQyJ9rwa6yd-2oyR4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCWOA1ZGywLbqmigxE4Qlvuw',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'GHwN2HfiEwvumTgjw-DJe_n37tE',
#                                             'id': 'UgxvQyJ9rwa6yd-2oyR4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UC1kHOqDcZr1cwskyx8RUjOA'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UC1kHOqDcZr1cwskyx8RUjOA',
#                                                         'authorDisplayName': 'Sankalp '
#                                                                              'Shrivastava',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKYdkSwfXie5aH5VLG60FWtGRaO4DhqE2m4nXcUw2g=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCWOA1ZGywLbqmigxE4Qlvuw',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2023-11-07T21:36:12Z',
#                                                         'textDisplay': 'I want '
#                                                                        'original '
#                                                                        'soundtrack '
#                                                                        'in '
#                                                                        'this.. '
#                                                                        'else I '
#                                                                        "ain't "
#                                                                        'watching',
#                                                         'textOriginal': 'I '
#                                                                         'want '
#                                                                         'original '
#                                                                         'soundtrack '
#                                                                         'in '
#                                                                         'this.. '
#                                                                         'else '
#                                                                         'I '
#                                                                         "ain't "
#                                                                         'watching',
#                                                         'updatedAt': '2023-11-07T21:36:12Z',
#                                                         'videoId': 'QOg9LUIvaig',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'QOg9LUIvaig'}},
#            {'etag': 'lzooRnBF3dIIrmMHBhruuYpf7vU',
#             'id': 'UgwhFG8U-GQVDyJ8VlN4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCWOA1ZGywLbqmigxE4Qlvuw',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'XZULA4UQ31igYcznulEhQLLaTf0',
#                                             'id': 'UgwhFG8U-GQVDyJ8VlN4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCJ2u71XYxUrTd1rs5zWMr2A'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCJ2u71XYxUrTd1rs5zWMr2A',
#                                                         'authorDisplayName': 'Jesss '
#                                                                              'C',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKbr5ak_oX1KVjTCgcQLbcS6HfPfzYGvXS1Cch4f8w=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCWOA1ZGywLbqmigxE4Qlvuw',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2023-11-07T12:17:58Z',
#                                                         'textDisplay': 'They '
#                                                                        'had '
#                                                                        'done '
#                                                                        'it for '
#                                                                        'One '
#                                                                        'Piece, '
#                                                                        'pleeeease '
#                                                                        'do it '
#                                                                        'for '
#                                                                        'ATLA! '
#                                                                        '🥹',
#                                                         'textOriginal': 'They '
#                                                                         'had '
#                                                                         'done '
#                                                                         'it '
#                                                                         'for '
#                                                                         'One '
#                                                                         'Piece, '
#                                                                         'pleeeease '
#                                                                         'do it '
#                                                                         'for '
#                                                                         'ATLA! '
#                                                                         '🥹',
#                                                         'updatedAt': '2023-11-07T12:17:58Z',
#                                                         'videoId': 'QOg9LUIvaig',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'QOg9LUIvaig'}}],
#  'kind': 'youtube#commentThreadListResponse',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpZElCZ0JFZ1VJaHlBWUFCSUZDSWtnR0FBWUFDSU9DZ3dJOXRXb3FnWVF1SnZGcXdF',
#  'pageInfo': {'resultsPerPage': 20, 'totalResults': 20}}
