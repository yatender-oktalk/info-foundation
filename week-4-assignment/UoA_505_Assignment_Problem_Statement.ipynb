# %% [markdown]
# ## Course1 : Foundation of information

# %% [markdown]
# **Assignment**: Data extraction and analysis from social media platform Youtube ( 30 Marks )

# %% [markdown]
# **Problem statement**
#
# Videos are a fast growing medium where people communicate, share knowledge, showcase skills etc. YouTube is one of the biggest platforms which hosts videos. The YouTube platform hosts content from many different professions/arts/ cultures across the world.
#
# People can express their opinion about the video in the form of likes, dislikes, comments which are features provided by the YouTube platform which provides the information on the sentiment about the video.
#
# The assignment involves the steps on programmatic data extraction from YouTube on which analysis can be conducted to understand various attributes related to a video.

# %% [markdown]
# **Steps to be performed**

# %% [markdown]
# 1. Connect to the Youtube API using a Python client ( 5 Marks )

# %% [markdown]
# > 1.a Create a YouTube API key (3 marks)

# %% [markdown]
# > 1.b Install the Google API python client  (2 marks)

# %% [markdown]
# refer to the [supporting](https://developers.google.com/youtube/v3/getting-started) link on how to create YouTube API Key

# %% [markdown]
# Reference link : https://developers.google.com/youtube/v3/quickstart/python

# %% [markdown]
# - I enabled the API key from the google cloud console and generating the API key.
# - To connect to the youtube, we enabled only for the public data access so we don't have to deal with the oAuth related stuff as we don't need any personal data of the users.
# - After enabling the API key we would need to install the dependency via pip
#
# We used the following command to install in our virtualenv as I'm using the pip.
#
# ```
# pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# ```

# %%
import json
import csv
import pandas as pd
import numpy as np

from pprint import pprint
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

YOUTUBE_API_KEY = 'AIzaSyDgc2_04BksQXvYmNgNPqCZwEvMRaZ85fI'
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'

youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=YOUTUBE_API_KEY)

# %% [markdown]
# 2. Search and extract the data

# %% [markdown]
# > 2.a Search videos related to the query string  “avatar movie”
# (For this part, choose/search one video of your choice and perform data collection steps on that specific video ) (3 marks)
#
# > Output expected : ID, Snippet with following attributes Channel ID, Video Description, Channel Title, Video Title

# %% [markdown]
# Reference link:  https://developers.google.com/youtube/v3/docs/search/list

# %% [markdown]
# We will only create the collection for the video as we don't really care about the playlist and channel now, notherwise that can also be done via fetching the particular type
# **Also, just for reference, instructions here and in the PDFs were different, which is not good.**

# %%
def youtube_search(search_query, max_results):
    # Call the search.list method to retrieve results matching the specified
    # query term.
    search_response = youtube.search().list(
    q=search_query,
    part='id,snippet',
    type="video",
    maxResults=max_results
    ).execute()

    videos = []

    # Add each result to the appropriate list, and then display the lists of
    for search_result in search_response.get('items', []):
        if search_result['id']['kind'] == 'youtube#video':
          videos.append(search_result)

    return videos

def extract_data(video_data):
    # ID, Snippet with following attributes Channel ID, Video Description, Channel Title, Video Title
    video_snippet = video_data["snippet"]
    data = {
            "ID": video_data["id"]['videoId'],
            "Snippet": {
                "Channel ID": video_snippet['channelId'],
                "Video Description": video_snippet['description'],
                "Channel Title": video_snippet['channelTitle'],
                "Video Title": video_snippet['title']                
            }
           }
    pprint(data)

# We will fetch only 5 results
videos = youtube_search("avatar movie", 5)
extract_data(videos[0])
# Out:
# {'ID': 'PLtgIILX7E8',
#  'Snippet': {'Channel ID': 'UC0A86RKLCqTEUna3hPlEpzg',
#              'Channel Title': 'Superhero FXL Games',
#              'Video Description': 'AVATAR Full Movie 2023: Fallen Kingdom | '
#                                   'Superhero FXL Action Movies 2023 in English '
#                                   '(Game Movie). Best Action Game ...',
#              'Video Title': 'AVATAR Full Movie 2023: Fallen Kingdom | '
#                             'Superhero FXL Action Movies 2023 in English (Game '
#                             'Movie)'}}

# %% [markdown]
# > 2.b  Provide the following statistics for query string “avatar movie” of top 50 videos sorted by relevance in the US region ( 7 marks )
#
# > Output expected: video ID, title, no of views, no of likes,no of comments exported to CSV file

# %% [markdown]
# Reference link: https://developers.google.com/youtube/v3/docs/videos/list

# %%
def youtube_search_with_region(search_query, max_results, region_code):
    search_response = youtube.search().list(
        q=search_query,
        part='id,snippet',
        type="video",
        regionCode=region_code,
        maxResults=max_results
    ).execute()
    
    videos = []

    # Add each result to the appropriate list, and then display the lists of
    for search_result in search_response.get('items', []):
        if search_result['id']['kind'] == 'youtube#video':
          videos.append(search_result)

    return videos

def video_id_list(video_list):
    video_id_list = []
    for video in video_list:
        video_id_list.append(video['id']['videoId'])
    return video_id_list


def write_csv_file(data, file_name):
    df = pd.DataFrame(video_data)
    df.to_csv(file_name)


def extract_video_information(video):
#     video ID, title, no of views, no of likes,no of comments
    statistics = video['statistics']
    content = video['contentDetails']
    video_id = video['id']
    return {
        "video_id": video_id, 
        "no_of_likes": statistics.get('likeCount', 0),
        "no_of_views": statistics.get('viewCount', 0),
        "title": video['snippet']['title'],
        "no_of_comments": statistics.get('commentCount', 0)
    }
    
        
def video_information(video_ids):
    search_response = youtube.videos().list(
        part='id,snippet,statistics,contentDetails',
        id=video_ids
    ).execute()
    
    videos = []
    for search_result in search_response.get('items', []):
        if search_result['kind'] == 'youtube#video':
          videos.append(extract_video_information(search_result))
    
    return videos

videos = youtube_search_with_region("avatar movie", 50, "US")
video_id_list = video_id_list(videos)
video_data = video_information(video_id_list)
# Export the file
write_csv_file(video_data, "./data.csv")

# %% [markdown]
#  3. Analyze the exported data obtained in 2.b and carry out the following tasks (15 marks )

# %% [markdown]
# > 3.a Sort the data 2.b  by top 10 comments in descending order and consider the video IDs and Titles of top 10 videos which have highest comments. (3mark)

# %%
# Create the dataframe
def sorted_data(file_name):
    df = pd.read_csv(file_name)
    df['no_of_comments']= df.no_of_comments.astype(int)
    sorted_data = df.sort_values(by='no_of_comments', ascending=False)
    
    return sorted_data

# As it's not mentioned the no_of_comments in the description but still writing as 
# it's easy to check the number of comments
data = sorted_data("./data.csv")

pprint(data.loc[:, ["video_id", "title", "no_of_comments"]].head(10))
# Out:
#        video_id                                              title  \
# 2   d9MyW72ELq0        Avatar: The Way of Water | Official Trailer
# 0   waJKJW_XU90  Avatar: The Last Airbender | Official Teaser |...
# 9   a8Gx8wiNbs8  Avatar: The Way of Water | Official Teaser Tra...
# 42  2r71I8lvTIA  The Last Airbender Film: How it Disrespected a...
# 4   5PSNL1qE6VY  Avatar | Official Trailer (HD) | 20th Century FOX
# 41  p_GgAHd5siE                           TOPH: An Avatar Fan Film
# 35  T5vdPy7nbRQ                         Avatar Element Animation 2
# 34  RGx8rYbRVR4  Why People Hate Avatar: A Lesson In Lazy Comme...
# 25  f5Zx8iPek5I  Avatar 3 Will Introduce The Dark Side🔥 Of Na'v...
# 31  QOg9LUIvaig  AVATAR: THE LAST AIRBENDER | Water, Earth, Fir...
#
#     no_of_comments
# 2            43090
# 0            31596
# 9            29018
# 42           27174
# 4             8939
# 41            5399
# 35            4630
# 34            4044
# 25            3998
# 31            3976

# %% [markdown]
# > 3.b Use a suitable method to retrieve comments of those top 10 videos from 3.a. For doing this, write a program to loop through each video id from 3.a and pass in the part parameter set to "snippet", to retrieve basic details about the comments. Execute this request and print the response using the pprint() method.
#  - Note: pprint() will print out the response from the API in a more human-readable format.
# - Reference link:  [link](https://developers.google.com/youtube/v3/docs )
#
#
# > **Output expected** : Use the python library “ pprint “ to print the output of the program with the following properties  etag, items, id , kind, snippet and snippet to have the text display field which represents the comment of videos.

# %%
# Call the API's commentThreads.list method to list the existing comments.

def get_comments(video_id):
    try:
        results = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        textFormat="plainText"
        ).execute()

        return results
    except Exception as e:
        return []

def format_comment(comments):
    formatted_list = []
    if len(comments) > 0:
        for comment in comments['items']:
            cmt = comment['snippet']['topLevelComment']
            comment_data = {
                "etag": comment['etag'],
                "items": {
                    "id": cmt['id'],
                    "etag": cmt['etag'],
                    "kind": cmt['kind'],
                    "snippet": {
                        "textDisplay": cmt['snippet']['textDisplay']
                    }
                }
            }

            formatted_list.append(comment_data)

        return formatted_list
    else:
        []

def get_all_video_comments(video_list):
    comments_list = []
    for video_id in video_list:
        comments = get_comments(video_id)
        comments_list.append(format_comment(comments))
    
    return comments_list
        
data = sorted_data("./data.csv").head(10)

# print(data["video_id"])
comments_list = get_all_video_comments(data["video_id"])
# comments_list = get_all_video_comments(["HR2kbOK8i6I"])
pprint(comments_list)
# Out:
# [[{'etag': 'XsCS-xW3bre2AtAidI5ZudN6cAc',
#    'items': {'etag': 'IUN4pJhnNNF0jPN74vd4UK0NmLg',
#              'id': 'Ugy9R8bfFFOJbZWLMY54AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Damn that background scores hit 😳'}}},
#   {'etag': 'bkmV9Tisb-1OzAB3453DY4jwF30',
#    'items': {'etag': 'PvGJg4jfKBcBoDCq5Z1N7eotQiA',
#              'id': 'UgxJQ2TO0o1yAwQJv_Z4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Teaser is better than trailer i '
#                                         'think❤'}}},
#   {'etag': 'c2Qs5JrzYoPL8jB5f2RMObmWVCk',
#    'items': {'etag': 'vfZ2nxMgVVg3eCTu9mM45-_TbDs',
#              'id': 'UgznsmdN7aCoc2mEJdN4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Everyone that must have liked this '
#                                         'movie must be a bad parent and has a '
#                                         'zero observational. Or is filthy Rich '
#                                         "that's a bad parent that has zero "
#                                         "observational skills and it's pretty "
#                                         "damn stupid too. It's like saying the "
#                                         "last Expendables was good. Yeah let's "
#                                         'just show people how to use brass '
#                                         'knuckles in a fight. Brass knuckles '
#                                         'are for pussy!'}}},
#   {'etag': 'GwCpCK39315mP7WasQM-xJyLwvY',
#    'items': {'etag': 'VU9kq7xmUYdPu23Xx45hzu3OSb8',
#              'id': 'UgyNmgWIx8JHWanDlF54AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Wow it’s been a year still love this '
#                                         'movie!!'}}},
#   {'etag': 'w7yDJh6a4uE0xpCzyD8JmPs2jhc',
#    'items': {'etag': 'JwZEbTArqUEIPzd_LhJU-_6UmxE',
#              'id': 'Ugwi9xmqkTK_MgptstR4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I Know It’s Been A Year, But Why Do I '
#                                         'Feel Nostalgic Watching This?'}}},
#   {'etag': 'Be9OnP9kAAd2VoOH4F72I41wYr8',
#    'items': {'etag': 'YQ55ylbEGzIOLMRLUOdCkmvgnE4',
#              'id': 'Ugy3C7msAhQAjj5Qnm14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'today this trailer is 1 year old'}}},
#   {'etag': '88ewV0zh5LfxL5KMF6HaNHERDtc',
#    'items': {'etag': '_FrwlA6mTc4lZRQ5iXXe0xyVc3Q',
#              'id': 'Ugx89J02VZDY-yzwh454AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "It's been a year. Happy anniversary, "
#                                         'Avatar 2!'}}},
#   {'etag': 'sOaHHJdhQmyojWzEDC_N0kilv4c',
#    'items': {'etag': 'EJhDayM0bZztmDvn0Ehz5SFbKVM',
#              'id': 'UgwNDfb3LVn-VGkX1Dh4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "It's been one year. Time is fast!"}}},
#   {'etag': '9_Imj4j0TXB21ALxi1RMdfMh_zk',
#    'items': {'etag': 'TrrpIqS_MJs17Rt_tmwfs_mIOK4',
#              'id': 'UgzI-bHjQ9yUsY00qxx4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': ''}}},
#   {'etag': 'eFrIluXJ9VB6lD8QH4ShWoXkTjA',
#    'items': {'etag': 'ngTklOnecVh7SwIOjyN9hIs_01Y',
#              'id': 'Ugxzts79CO4bGcNdH7t4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'No idea how a race so Primitve and '
#                                         'peaceful can beat an advanced warlike '
#                                         'species like us.The tech looks too '
#                                         "much like halo. I'm Suprised Master "
#                                         "Chief didn't show up and mop the "
#                                         'whole damn planet .Sequel: Humans '
#                                         'return and wipe out the blue heathen '
#                                         'treehuggers. Later in history books: '
#                                         '"It turned out that their spears were '
#                                         'no match for our nukes." I never '
#                                         'understood why it was they thought '
#                                         'that humanity would just count their '
#                                         'losses and leave Pandora alone. If '
#                                         'they really wanted that  Unoptanium '
#                                         'or whatever it was called, surely '
#                                         "they'd send a proper military force "
#                                         'next time. When the East India '
#                                         'Company failed to secure India, Great '
#                                         'Britain annexed it and put it under '
#                                         'martial law. A private company nearly '
#                                         "wiped out the Na'vi, what's to stop a "
#                                         'full military invasion? Just seemed '
#                                         'like a bit of a plot hole to me.'}}},
#   {'etag': 'T1V4QQ3Ab5DOWhp6yJ8yWZjJZ8Q',
#    'items': {'etag': '3ogEPowaYzhY4F-GH6wMeMFBp9Y',
#              'id': 'Ugzp5BdLeXr0jfcysKd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I cant believe this video came out 1 '
#                                         'year ago.. feels like yesterday ❤'}}},
#   {'etag': 'yYSPXWsuV28ldljk6w7Fz2V7ReE',
#    'items': {'etag': 'XSM7UFzXl0iPcoeFOO_3JUXpDcQ',
#              'id': 'UgztV04r1VrNK19VDyd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'よく考えたよな'}}},
#   {'etag': 'cfCxe9bxipk19NAQLuQKkhk59sE',
#    'items': {'etag': '5XUeV3fOjEW-yb6UHoZyFHcF9GE',
#              'id': 'UgwBBt2aWyNZMYevfFh4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'This trailer was dissapointing... in '
#                                         'the good meaning. I mean.. the actual '
#                                         'movie is at least 10 times more '
#                                         'exciting than this trailer. So it was '
#                                         'positively dissapointing. Worth '
#                                         'was/is the hype.\n'
#                                         "Can't wait for the 3rd movie, the "
#                                         'hype-level is higher than by any '
#                                         "movies before. And it have it's "
#                                         'reasons.\n'
#                                         'Just hope they will drop an '
#                                         'early-teaser trailer ,like one '
#                                         'arrived more than one year before '
#                                         'Star Wars. If Avatar 3 has been '
#                                         'delayed, it would be nice.'}}},
#   {'etag': 'UcOtBHQybgNGkHvalXILd2FgUyM',
#    'items': {'etag': 'QQQaglm7UQBFMCb3kc1SgdDGtJ0',
#              'id': 'UgwoCwpoPGwUxpRGV6Z4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'പുള്ളിക്കാരന്റെ brain നിൽ തോന്നുന്നത് '
#                                         'ഇറക്കണം....'}}},
#   {'etag': 'tnth5TsoCyfRsbUPNBecXlWD8us',
#    'items': {'etag': 'PtKLW-gNg14WceOCKSdyht2Whc0',
#              'id': 'UgyhdYJV8SetzbfMdIR4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Avatar 2 was amazing! Hats off to the '
#                                         'entire team!'}}},
#   {'etag': 'hlONEikz0WAaDUchYJlWOyQQWDo',
#    'items': {'etag': 'kgcEgbosyH_9b9I9D93FkCZCKgw',
#              'id': 'UgyqxGDJvy_8s6PVLwR4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "I've read far too many detailed "
#                                         'reviews that have thankfully saved me '
#                                         'from wasting my time on this. Same '
#                                         'villain, lazy script, too long etc '
#                                         'etc. First one was..meh...ok. Not '
#                                         'surprised this one is a miss for '
#                                         'me.'}}},
#   {'etag': 'kYL74aDBACncR9vCZqYgjous_j0',
#    'items': {'etag': 'qwrV5Xe-N3GuiPkS42lPjzL_zVw',
#              'id': 'Ugz8YFXgnkQWg-nCZU54AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Masterpiece best theatre experience '
#                                         '🎭\n'
#                                         'James Cameron goat'}}},
#   {'etag': 'Fk6n5v_EZ-rzWXe-QC-pp8WAgBc',
#    'items': {'etag': 'exItqPqHxbjPhnYAs4C3gJMn8IQ',
#              'id': 'UgzOACVkh7oJqwA9hgp4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'missing those days 😔😔😔'}}},
#   {'etag': '7cvn7DB2GZCl3jMQo_KZQXGumV8',
#    'items': {'etag': 'rydlgPwIn7zlpbhcfKQKsPUC_YA',
#              'id': 'UgxIhnGJVFQPkdcRCxh4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Dekh roya sala.. ROFL🤣🤣'}}},
#   {'etag': 'x5ObjsYB8r0B_UFcWW8dcMigIHc',
#    'items': {'etag': 'ulNaXO71GFrKbXOaMOzL10dovrI',
#              'id': 'UgynqLAE9MT4RRCh-yB4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "Just watched it and i don't know why "
#                                         'i waited so long for doing that. '
#                                         'Maybe i was afraid for being '
#                                         'disappointed in movies again. But i '
#                                         'came back to watch the trailer '
#                                         'immediately, Avatar 2 is breathtaking '
#                                         'awesome and a must watch!! Trust me '
#                                         'you will not be disappointed! Big '
#                                         "shout out to all the makers. I can't "
#                                         'wait for Avatar 3.'}}}],
#  [{'etag': 'O8geUUiHncHV0SsKmoty7spFccs',
#    'items': {'etag': 'ggZwhNLVwyKp-OlWAw_eeZelYjU',
#              'id': 'UgyDR3lN3G3SeOWXqD94AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "I can't wait for this netflix series "
#                                         'to start!! I really hope it lives up '
#                                         'to the Anime!! The trailer looks '
#                                         'awesome, hope they include all the '
#                                         'details of the original story!! If '
#                                         'this series becomes a success, who '
#                                         'knows, the Anime might get revived '
#                                         'too!!'}}},
#   {'etag': 'zan__z-PQo9mgZwyzWvJb-BeIVg',
#    'items': {'etag': 'WGzoSWd976muFu-4Rr6z6StgqqU',
#              'id': 'UgwguKu8W_9HJEwBaVh4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Ozai looking majestic af, by looks '
#                                         "alone he is the one I'm liking the "
#                                         'most for now.'}}},
#   {'etag': 'Bx85ww0GHpFiEzTuR_R7gD5mBdY',
#    'items': {'etag': 'r_z1L0IlwTDZgrv5ht8QV6rWLxg',
#              'id': 'Ugwk4ZrWJW4NfPgSwP14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Why would I watch a worse version of '
#                                         'the same thing?'}}},
#   {'etag': 'HVVh96_51VnJJdjCLUjELSLN25s',
#    'items': {'etag': 'TKy6oH_LUIlzVDAJm3NdtmYEqlw',
#              'id': 'UgzPPbg6pZMfjePO3Gp4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I mean, it definitely looks better '
#                                         'than the movie'}}},
#   {'etag': 'sCt6uKJINBNWN1tkTCZM-lmg9Zs',
#    'items': {'etag': 'UeRoWwTHneya9RgoBGzS-q68mvM',
#              'id': 'UgyYl2TN8tCQytYqxNd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "Please don't mess this time 😅"}}},
#   {'etag': '1bZ-XDwVZwT5gY0k-X8wof4NW40',
#    'items': {'etag': 'lP0R5_ZksWeGqCzHWaTRQ5vYVq0',
#              'id': 'Ugwz8fJ7OrLgg86yL0d4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'You can’t do worse than the first '
#                                         'one.'}}},
#   {'etag': 'iicIVvpNGc7AfD57f1V0eIa-ido',
#    'items': {'etag': 'SH8MKgVpskXct2zDog80HUiEKa8',
#              'id': 'UgwRXQNnnHwxxpQThLl4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "Momo looks kinda dumb, but I'm "
#                                         'excited for everything else!'}}},
#   {'etag': 'SjsU6MiTZJc5oAJMM7sTQZrdQGw',
#    'items': {'etag': 'TRisqmOothtQzWhNap1vfbQH0OE',
#              'id': 'UgyspnJr2b8t_CFV3Rx4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I’m hypeddd'}}},
#   {'etag': 'LEAVxxqADdSFE-caos8YKOvtfRI',
#    'items': {'etag': 'slQzzWj_0xxLB6hKQaAnXOq0zAg',
#              'id': 'Ugxvbwce91vryJFuxwB4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Not again...'}}},
#   {'etag': 'DmcI4SsyunZsjSZJLHUt4dYGD4k',
#    'items': {'etag': 'hH0IpPvTiPA7OuqZ33srlO7YKsw',
#              'id': 'Ugw-0a3YxfJ1zwSUXgZ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "Wow. I'm still keeping composture "
#                                         'towards it, but when those few notes '
#                                         'started, a few tears came up. That '
#                                         'soundtrack is as magical as ever.'}}},
#   {'etag': 'ti3m3feXiGnX1e5UNlxMLOwRjRs',
#    'items': {'etag': 'Y5XQ0d5NQv0awE_7zgGTyNoIkyY',
#              'id': 'UgyRsD5rbZ4UemvsbM94AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'No. Absolutely not. Why couldn’t you '
#                                         'just let it be a flop? This shit is '
#                                         'horrid. Atrocious. As cringe-worthy '
#                                         'as it gets. The original version that '
#                                         'flopped was who know how many times '
#                                         'better than this.'}}},
#   {'etag': 'BcX6Ms8U5RFYiqZdKluv_RCnLDc',
#    'items': {'etag': 'U7r2Uv6MKaoL15fQ-x90FywDwts',
#              'id': 'UgwhTsy6T5k7-mkokNt4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "omg it's actually not a flop??"}}},
#   {'etag': 'SMpsxTr86iNt0SDlZfmmO0dIVhw',
#    'items': {'etag': 'VsaYtD41fGEmNodynsDR3CN9RcI',
#              'id': 'UgxZ5b2-bsfhquDRZgR4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Omg i cant wait a 😮😮'}}},
#   {'etag': 'XmPCc8KVR1ZgAaPPmqXu70HM-fA',
#    'items': {'etag': 'OW4Y18PYjjNW0S1hEVTNMHo0evg',
#              'id': 'UgygsM0Yl_Bm1v6TLZF4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'The last Airbender is actually a very '
#                                         "good work that's why when I've seen "
#                                         'the first live action of it I was '
#                                         "pissed and disappointed. It didn't "
#                                         "live up to it's true form hope this "
#                                         'netflix one would be good'}}},
#   {'etag': 'mWQW32fUiVIHLCNCJzHyrMDh464',
#    'items': {'etag': 'xLzVyK5i5qRWaoOTB21bs1Ucfaw',
#              'id': 'Ugzcxh4rxwyYzk_uXVd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I honestly think Netflix is trying '
#                                         'too hard, why not make some more '
#                                         'original content like stranger '
#                                         'things, instead of ruining beloved '
#                                         'childhood/anime shows'}}},
#   {'etag': '8CJRYQNupN8Fovd7S1a2L5Kc7gw',
#    'items': {'etag': '88slWHyf4jDrAq5Okm7b9eqdxNI',
#              'id': 'UgzNrlzPQHwRx62XH5J4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'We have Momo in this series!'}}},
#   {'etag': 'y2kxMrIqFDWuT5Nt2dBdkHj7KnE',
#    'items': {'etag': 'qgroPvX2Ws_X18vOY3D86EPlsUw',
#              'id': 'UgyeccstXwVg4vfpK_54AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Coool'}}},
#   {'etag': '8bUaP1FCgYmBkzmOIa7GEIyS_LM',
#    'items': {'etag': '51djnxRoGa6G505OA4fIQkQ9gWg',
#              'id': 'UgyOCsVaevgbfgyALZd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Aaaaaaaaaaaaaaaaaa'}}},
#   {'etag': 'IVtvac0hz6NNman9Yfms2BvCKtY',
#    'items': {'etag': 'dsZBo8G_y80hMAr5xtbSiaTi55c',
#              'id': 'UgzYJZPcakB3PGYw1XN4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'YES YES YES YES! HOLY SHIT THIS LOOKS '
#                                         'GREAT!!!!'}}},
#   {'etag': 'a-biuX0IMHvCmC8i6fjl-3liWtY',
#    'items': {'etag': 'PtYnhdg05shlQVeZ-8VDoqLofkE',
#              'id': 'UgwViH5Jh0eOHSbhOK54AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I hope they didn’t take away all the '
#                                         'Chinese writings and cultures this '
#                                         'time'}}}],
#  [{'etag': '-77Gg_txex4NdHvLAIsKpqnA3Y4',
#    'items': {'etag': 'CT_2tTAmC7BY4Z9qIzyTiuXuhbU',
#              'id': 'Ugxj1nqJl9gl2zpgQKF4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Was always a treat to see this in '
#                                         'cinemas, when every other trailer had '
#                                         'a cheesy pop song or awkward '
#                                         'banter.'}}},
#   {'etag': 'A-lBLytRJsKnwApK48asMIEPBpc',
#    'items': {'etag': 'NJtl8zAUC69CDFAc7SyPhxeM3Ac',
#              'id': 'UgwN-sPfx8kOhKsGVi14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I expected humans in this movie to be '
#                                         'less stupid. I think the conflict '
#                                         'could be deeper if they acted like '
#                                         'true colonizers instead of aggressive '
#                                         'mold'}}},
#   {'etag': 'kkG5E_DvAocoPub_LUV9LVb-ul8',
#    'items': {'etag': '5nBY24Q1ql-OPFJkkwGtHUoJyHk',
#              'id': 'UgxUPmNFnenSGvRAO2J4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'This trailer is better than the '
#                                         'entire movie'}}},
#   {'etag': '_XsjcUvpvc65rLVi7M_qKP-Gh34',
#    'items': {'etag': 'd0rzLMPP5xTHAM4FonEnnckNmn8',
#              'id': 'UgxGBrUjYDCBjl_Z0Fl4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'It was a great movie i loved it. It '
#                                         'was one of the best movies i have '
#                                         'seen in my life. It was so amazing in '
#                                         '3d i loved it. I cant wait for avatar '
#                                         '3🥰 best movie!'}}},
#   {'etag': 'sOyL3UcacRCtM0hL72TEozflahw',
#    'items': {'etag': 'zmiI94qiUXJY4eY2b-Vg2EWVS64',
#              'id': 'Ugyv5G7EPflUdYOUVRx4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Still one of the best trailer ever '
#                                         'made'}}},
#   {'etag': 'PtVQcIpdC1sXvUCquRZjBiNn9tE',
#    'items': {'etag': 'vBAaqJVsrbZm0evjKZbZQwYvOQI',
#              'id': 'UgzRK4JXywQ5z3OC1rF4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'The primitive blue people all love '
#                                         'each other, and intergalactic '
#                                         "humanity doesn't give a f, part 2.  "
#                                         "James Cameron thinks you shouldn't "
#                                         'leave that behind.'}}},
#   {'etag': 'yMTofJr6N5Va-671VDkNLt83JQE',
#    'items': {'etag': 'kgrY-VZqV-iCX57rjIUAjquFPXk',
#              'id': 'Ugz9sAQfthpmPqK8faF4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': '🙏🙏🙏🙏🙏🙏'}}},
#   {'etag': 'j6GO8tE-T9WEHgfQvqw8ey2EUVc',
#    'items': {'etag': 'PHLpsOP3DxYjotgki-32cHTqtS0',
#              'id': 'Ugz9XqmDPqenZH_nF-14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'The clan of many.godzilla roar '
#                                         ',burning beds 🎶🎶🎶'}}},
#   {'etag': 'IYPEi3TVlPMeE1NrNwV1M_qZyck',
#    'items': {'etag': 'ycMWYx07V3GhLISI5t83Pn8SCQI',
#              'id': 'UgzuxDIeu7IdOq5Il5p4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Где перевод на Русский, козлы ?!'}}},
#   {'etag': 'b9XV_SX01HrSATh-Tato7AUSuco',
#    'items': {'etag': 'qs0M1cwWCqCEm8zm-Vn0shu6FDU',
#              'id': 'UgztQ9HI0ecPnqUL7PR4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Honestly I thought this teaser was '
#                                         'better than the main trailers, the '
#                                         'music was better and it really got '
#                                         'people exited for the movie'}}},
#   {'etag': '4igWJd5DDUmlGtd1vUEHckxWqp8',
#    'items': {'etag': '5JdpwpoJ1-CxI51kJ1_qVhsHQgQ',
#              'id': 'Ugytky0Xz9nb19GETE14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I just love avatar and everthing'}}},
#   {'etag': 'xC2iHsTQjrW0AJl1qtyatsoxAoQ',
#    'items': {'etag': 'WRY13hLby4IrYo5Ij6ks7-K6tzg',
#              'id': 'UgzJApFQ8dMaoZqFMtp4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Jesus is the Way, the Truth, and the '
#                                         'Life. Jesus said to Thomas, "I am the '
#                                         'way, the truth, and the life. No one '
#                                         'comes to the Father except through '
#                                         'Me". There is only one way to heaven. '
#                                         'That Way is Jesus and his word of '
#                                         'truth. No other can grant us eternal '
#                                         'life.'}}},
#   {'etag': 'iXAzlBoQ5iM-ovw9MA55NAfpT5M',
#    'items': {'etag': 'QJPJhTljYyDzVfhr6OpIP18Vipg',
#              'id': 'Ugx2b2Eg6jdTD3OY-vl4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Man i used to rewatch this trailer '
#                                         'over and over again. Cant believe how '
#                                         'much of its magic it lost after the '
#                                         'mediocre movie came out'}}},
#   {'etag': '9xfDm-LkOc2o_pf4qoZ8GFxjWkU',
#    'items': {'etag': 'GuDAe-F4zwFZ5IORBNj1uPq2zgQ',
#              'id': 'Ugwd-VB8zDWRnmLQyax4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Ever since this movie was released, I '
#                                         'saw it twice in theaters, and many '
#                                         'more times on Disney+ this has to be '
#                                         'the most triumphant, beautifully '
#                                         'created movie that I have seen in a '
#                                         'very long time'}}},
#   {'etag': 'wIylo8JhH4UWUFcXgB08wvIUVQY',
#    'items': {'etag': 'ARNFNyKfKnqLk9duEVGdhtqeD6w',
#              'id': 'UgyfL8440vET3YqI2xB4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'If only...'}}},
#   {'etag': '7uGWVS0jdiL8zFeE-XvvtuRD5tg',
#    'items': {'etag': 'LDWlq5Lhsun09bkny7bu3LQv0SE',
#              'id': 'Ugw437XWmoqp7dKadDZ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Avatar 3 delayed from December 2024 '
#                                         'to December 2025'}}},
#   {'etag': 'cQQJ7Rns_1fWFH8kDcZqu_SNgCo',
#    'items': {'etag': 'lLW7_XGy4_Py8q0f5NHHlRRKm2M',
#              'id': 'Ugy8ZFY0G4Fm1ZstGCd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': '10/10 movie. Flawless.'}}},
#   {'etag': 'SQMJ5nsfZyUBBNqv9rONvJMDHvs',
#    'items': {'etag': 'md3HQ7kFHwkdoJengDAuQlApRxA',
#              'id': 'UgzRbWfXG756v4gxhil4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Too bad the movie was a letdown 😢'}}},
#   {'etag': 'lLi-0pH8qb4aVSB4M2jfM3G0t00',
#    'items': {'etag': '5Xy58Ih3hP6TRFQCYWlgo4NtxV0',
#              'id': 'UgzzhU2OuhMsUGUX7It4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Still can’t believe its all real, '
#                                         'like I remember rewatching this '
#                                         'trailer thousands of times over just '
#                                         'to hear the music and see the visuals '
#                                         'and get all excited!!! Agghhhh 💙'}}}],
#  [{'etag': 'B7z05MNMqID13q9n1UtptWOgsIc',
#    'items': {'etag': '04y5jA_MglVNbi0A27GTweG76VY',
#              'id': 'UgzkWRrsA6XkiTsASk14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'The movie could be worst but it not '
#                                         'the actors fault it the director they '
#                                         "didn't have everything right part of "
#                                         'the cartoon series.'}}},
#   {'etag': 'IMYP49F8NTBGrGAlK20My4w7O3w',
#    'items': {'etag': 'nVL8dXLkjOOAu94_zdAfz5c8mQw',
#              'id': 'UgzbWmKLUrCFv57GFqd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I don’t think it was shyamalans fault '
#                                         'I think it was the company he worked '
#                                         'with'}}},
#   {'etag': 'Iahd6bKjZJvPZY3ErV-bOzelOWY',
#    'items': {'etag': 'X3eUcY4iqsmYMpPfuRCMimeuWs4',
#              'id': 'Ugzg9y2YxSSR8Gq_Lgd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "I didn't even watch it after seeing "
#                                         'the trailer😅😅'}}},
#   {'etag': 'R1RTTZLQCX-dutxmCbsEh5Io7c8',
#    'items': {'etag': '3mvrz5QB6K8800I1qdNc34oosCs',
#              'id': 'UgyyGs7Sko0hOErZJSJ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I hated the flim. and I even hate '
#                                         'watching yoru break down of it just '
#                                         'making it even more glaringly obvious '
#                                         "how fucking bad this move is. it's "
#                                         'insulting on every level. omg this '
#                                         'brings up some serious indignation. I '
#                                         'gotta go do something else haha.'}}},
#   {'etag': 'HZ-4V1JxwUIosdi1Icz1OlNRFPo',
#    'items': {'etag': 'YwWs9evuzv5GKnoZBoxmbZ30uO8',
#              'id': 'UgxjriSM4ZsOWsyihw54AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I am now convinced that Shaymalan '
#                                         '(idk how to spell his name) was '
#                                         'trying to make an awful movie. Like '
#                                         'some of this shit is so obvious I '
#                                         'would’ve done better. And that’s '
#                                         'saying something because I am an '
#                                         'atrocious story writer.'}}},
#   {'etag': '-F0LLVlYL_uUzSw492MOT1A8Rp4',
#    'items': {'etag': 'vqGOQGimse-i8bPD1JWHZV3utSk',
#              'id': 'Ugwpz-I3vnSQohIKhY14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Dude, you clearly haven’t watched the '
#                                         'Dragon Ball Z movie 😂'}}},
#   {'etag': 'LumPrS9F7MALIL6O_2z4yggciwk',
#    'items': {'etag': 'hvGfXv3mYgcgadSVqWOZgTYe67Y',
#              'id': 'Ugw2lu-Erv9LMTRwxxx4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I watched the movie for a joke and '
#                                         'the only thing that I kind of like is '
#                                         'the design of the arrows on aang'}}},
#   {'etag': '2W5YU1LAA9Ffgv_bpQ4UEEn1lb4',
#    'items': {'etag': '0LvP41yz3HwOHbmIszwkOxQ5iHA',
#              'id': 'Ugxe8zWok7a7N-0EvsJ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'The director of this movie probably '
#                                         'never even watched the series! 😫😖'}}},
#   {'etag': 'ufqHmkA9bE_DJaWoIncZBlrHtVo',
#    'items': {'etag': 'EeJ2cBfg-JTgzcrNxVqQeeDVyws',
#              'id': 'UgxDyrlLDIk2kZh9CZN4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Where can I watch it?'}}},
#   {'etag': 'QSf8SqiW0_i0h4XMYR4F3-Gkrd4',
#    'items': {'etag': 'QVeRsN1_O2BMBdTYGQpjhV8NBs4',
#              'id': 'UgwEnp5pVB5L5QdPI8V4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'If I were a filmmaker I would consult '
#                                         'fans on how to make the movie of '
#                                         'their beloved series.'}}},
#   {'etag': '0evgLk-NdOqCBXMtcYJEaj_nf3E',
#    'items': {'etag': 'O0DnzVbShtI53QOygQbLtsMh1Dc',
#              'id': 'UgyqUS9fK9alo8pefDx4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "The crazy thing is that if they'd "
#                                         "showed us Zuko's desperation when "
#                                         'Aang escapes the ship, him saying '
#                                         '"for a moment..." and letting it '
#                                         'trail off could have been really '
#                                         'powerful. Dev Patel actually '
#                                         'delivered that line pretty well.'}}},
#   {'etag': 'eECoNZhuPbu_Hfqx-eW4d_1LU6k',
#    'items': {'etag': '5_ohpp0rxUZLPCZVaSZbhFQuiuk',
#              'id': 'UgwsCjPi2fSPNbocCzd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "I really don't mind this movie."}}},
#   {'etag': '1OpAqJXykd3PrFXy9JyxWYTyk_A',
#    'items': {'etag': 'l9if0aPTSnzbUdPQ8YhJBnRzuiI',
#              'id': 'Ugzk5Afu-ZdrvYleK054AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'The bending is also so much weaker '
#                                         'and slower like it would be if u had '
#                                         'a dream about this and everything u '
#                                         'tried to do was super slow and '
#                                         'powerless'}}},
#   {'etag': 'FCGLjJRUQ90VXTzgfn_V66B7ooU',
#    'items': {'etag': 'mEV5bnxvZP6VXi4ypPyHy0gd6-A',
#              'id': 'UgyHQFPO_bJyJ75zfEF4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Sokka in this movie acts like a '
#                                         'character from season 4 if Attack on '
#                                         'Titan. Bro is just a horribly '
#                                         'written, insanely shallow, and a flat '
#                                         'as cardboard Eren Yeager.'}}},
#   {'etag': 'ZwQphOsU64e7D86lT7XOZysD8Yw',
#    'items': {'etag': '51DJbqUJ8iq1RuEzQ4IKxa6fr3k',
#              'id': 'Ugy6tWcoQAyB3xNlG8Z4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'The last airbender and legend of '
#                                         'korra are awesome shows but the last '
#                                         'airbender movie was shit.'}}},
#   {'etag': 'zDAWBPSBiOWakwCFmH5pNQJQlRA',
#    'items': {'etag': 'zrQgXD3dmtZrT3esSKfAKZSclaM',
#              'id': 'UgxL9U6IUkuOC9fjaeZ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'The movie just made me mad. It made '
#                                         'me cry.'}}},
#   {'etag': 'FJiH7rUkz3nkshoFrcYncKcvMbw',
#    'items': {'etag': 'yMius_cTe9r1GNi8ULyinoE0fn0',
#              'id': 'UgyvzNvUWS2GTtP89XB4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'this shit hurt my soul first watching '
#                                         'it.'}}},
#   {'etag': '8dkl7vSISXqySHjZR6RadBSj9Po',
#    'items': {'etag': 'HeJwvsxM797-nG5nP0LEQ3dcbQg',
#              'id': 'UgwlRPLB4rl7PCRYsb54AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'i am ong, the ovatar i ran away but i '
#                                         'came back'}}},
#   {'etag': 'kqbpjnDiG_znS2ZtLfZAQmnz9xc',
#    'items': {'etag': 'L3ui48elYiBD8yaWtvwLsvk_yj4',
#              'id': 'UgxOYmWenqKf0XauhE14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'As much as I love the series, I will '
#                                         'never get over with how bad this '
#                                         'movie was, probably the worst one in '
#                                         'my opinion.'}}},
#   {'etag': 'tocurYCeWwi8cUCbHYc9IoCooec',
#    'items': {'etag': 'hsvRGZjSLAZZ9rCwiDC9p_FG0w0',
#              'id': 'UgxL-bG4wf7TATitwd54AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Nooooo they ruined aang and they '
#                                         'spoken so many things wrong it is so '
#                                         'sad and frustrating! '
#                                         '😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭'}}}],
#  [{'etag': 'PEIRrLrj8WUc8hr8a_XibcjCROA',
#    'items': {'etag': 'pGXr8hTFm40RNN5P7RtHVPn_DeU',
#              'id': 'UgyznIznXzth6N_LTZ54AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'this masterpiece got only 12m views, '
#                                         'but some shietty products of Marvel '
#                                         'gets the hundreds'}}},
#   {'etag': '0rEI9q5mEw0YyrA8Er44Rn068Q0',
#    'items': {'etag': 'VW3-OvemxU6l86bdvaCup2rBziw',
#              'id': 'UgzhBb1KePie9HKvxiN4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Avatar is a interesting movie to talk '
#                                         'about through all things, whether it '
#                                         'would be how it’s the highest '
#                                         'grossing movie ever, James Cameron '
#                                         'being a fabulous director, the '
#                                         'colorful world we go into, and epic '
#                                         'action.'}}},
#   {'etag': '6X7hxNxcke3Nwq9MwBJP65gms3M',
#    'items': {'etag': '-tQP9twoyYgtRqFeIF-QGtmbjbI',
#              'id': 'UgwFo5Bwf-p_su-IQZJ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I saw this trailer I believe in one '
#                                         'of my DVD’s and without seeing the '
#                                         'movie, it still looked so new and '
#                                         'good.'}}},
#   {'etag': 'XvB77XZnNYypLrl-PoCDllO_xs4',
#    'items': {'etag': '1Mcnzl0MQBTY4PJYSyMDrbjJeRY',
#              'id': 'Ugz7wtQodfA8lPHrIbF4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'what song is this? can someone please '
#                                         'help'}}},
#   {'etag': 'LHEJJvpc3NBxrlOz2MZQvcFnEtA',
#    'items': {'etag': 'ligzfuuIhU8CWOkKrXcKB4Z0ECE',
#              'id': 'UgyEtJ2WIw6CAF7Dqrx4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Everytime they start going over '
#                                         'Camerons previously accomplishments, '
#                                         'i get chills and i start '
#                                         'fist-pumping'}}},
#   {'etag': 'A-qmhkZZQlHdeU3M034mhSbsw_8',
#    'items': {'etag': 'ORIcT_ULGenGGzGcLYtl-L-O3xo',
#              'id': 'Ugx6j24P4KkUcSyzqD14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': '📌\n\n I love it ❤\n\n📌'}}},
#   {'etag': 'BMWFn6d9heSrOOikkawwZPrZOGw',
#    'items': {'etag': 'fQtC76J0bx6cgyOmIZFQf7Pj0vs',
#              'id': 'Ugxjaur63MaQ_yHJtAZ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Release dates: \n'
#                                         'December 10, 2009 (London)\n'
#                                         'December 18, 2009 (United States)\n'
#                                         'Budget: $237 Million Dollars \n'
#                                         'Box Office: $2,923,706,026 Billion '
#                                         'Dollars \n'
#                                         '(Worldwide)'}}},
#   {'etag': '7KtmZBHOaQb-qnooPOccjLqEqN0',
#    'items': {'etag': '94ik5lQcv8NtMFYv1TFA_ifh91g',
#              'id': 'UgzQhYZ7GxcId6gqrJd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "This is the best movie even it's gets "
#                                         'older'}}},
#   {'etag': 'K063zPBAepxU0Iu1uOhdkgLcbFY',
#    'items': {'etag': 'RTxuusvWjw18zIKq1w6eX3kc1s8',
#              'id': 'UgygA1vfSavYSHyldXl4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Ben bu filmi, bu zamana kadar nasıl '
#                                         'izlememişim, kendime aşırı derecede '
#                                         'şaşırdım. Çok gördüm, duydum ve hatta '
#                                         'açtım bir kısmını izledim ama devamı '
#                                         'gelmemişti. Bu akşam izleme fırsatım '
#                                         'oldu. Demekki bunu izlemek için '
#                                         'farklı bir boyutta olmak '
#                                         'gerekiyormuş. 😅 \n'
#                                         '\n'
#                                         'Filmi izledikten sonra, doğaya olan '
#                                         'sevgim ve saygım kat kat arttı. '
#                                         'Efsane ötesi... Her insanın ölmeden '
#                                         'önce izlemesi gerek.\n'
#                                         '\n'
#                                         'Ve şunu da eklemeden edemeyeceğim; '
#                                         'yorumları okuduktan sonra, yalnız '
#                                         'olmadığımı farkettim. Bu çok '
#                                         'sevindirici aslında. Umarım çok zaman '
#                                         'geçmeden yaşadığımız dünya, Pandora '
#                                         'gibi bir yer olur...'}}},
#   {'etag': 'rU5SZDyFn-RHwmHFG9j9bXaCleg',
#    'items': {'etag': 'qPrGwMFzD2huCsXPMS2XEGCsduQ',
#              'id': 'Ugzf1vW9KntUsTYqczp4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Palestine war in a nutshell'}}},
#   {'etag': 'W_Snhxenvb69WZBCWcMPLly62i0',
#    'items': {'etag': 'xBGxKVLARhYGfOYXRf-ViqQzL7s',
#              'id': 'UgwM4dAQEYcUGcpO4lR4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "I don't care what they say about this "
#                                         'movie This is one of the greatest '
#                                         'movies I ever seen not just CGI '
#                                         'presentation.'}}},
#   {'etag': '42pLvTd4wplLg96a2RG4HDWspWs',
#    'items': {'etag': 'YjeGiP3j22vYzKfguQXyH_6CI6M',
#              'id': 'UgxFNLvhbrzrmdvuBqp4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Humans are wonder creatures of God '
#                                         'but no doubt very '
#                                         'selfish.........❤'}}},
#   {'etag': 'ZoLzboLvdLAGJtOoBX3jB5OSKcE',
#    'items': {'etag': 'i8DAt76lNhqQThBTNAl10pk9ZLQ',
#              'id': 'Ugze7Oy2f4UZM18zcN14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "13 years later they're back"}}},
#   {'etag': 'ZWAkOmkWayojN7WhssyoREjO1Hs',
#    'items': {'etag': 'vchYflpTp-QsXOVqbzJz5BdURhk',
#              'id': 'UgyDCXckK0lh7eDLNV14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'We Need to push for Sam Worthington '
#                                         'to be the westworld gunslinger for '
#                                         'the new Westworld movie!'}}},
#   {'etag': 'tncs6G3SPrqsHXjJHc5UhKcT3G4',
#    'items': {'etag': '4DQysjp9c5-Gv1arMpH8EKgeNNs',
#              'id': 'UgxWoBRDny_OszNLCgd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "L'histoire de avatar me fait penser "
#                                         'un peu au film danse avec les loup '
#                                         'mais à la sauce science fiction'}}},
#   {'etag': 'LnxiqpECs1w2fqPE4Kyx7WsqJY8',
#    'items': {'etag': 'Jo6T0yUCP9p8Rbo_koboc2EKuUs',
#              'id': 'UgzvCCpGX0DTZp9W9QZ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Favorite movie...'}}},
#   {'etag': 'nK8zkkDT_Qumc6fq09Wwb6C3JG0',
#    'items': {'etag': 'hmx1RS7G4tv8HVvaou_fz7rtYlc',
#              'id': 'Ugyj9Kuj3vWMQUGakYV4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Daily watching trailer'}}},
#   {'etag': '111QmR-su0zWhbpmzueJ82I7hrQ',
#    'items': {'etag': 'JQinnHXJNl_wmu1rBSLhkBjhkxo',
#              'id': 'Ugxq1y7xeLqyAN4Jz8t4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'FFX had better graphics'}}},
#   {'etag': 'eQi_Y-r6OlaijsJCcd-uLmWojfM',
#    'items': {'etag': '_5mKisbXLBc5aCMNlidVNRM3vms',
#              'id': 'UgxbxImQIosUa6068iZ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Although Avatar broke titanic box '
#                                         'office record .. Titanic is bigger '
#                                         'globally .. what other film can say '
#                                         'that ? This is a movie that’s '
#                                         'transcends by language'}}},
#   {'etag': 'PghF3yclXwBI7qGfxIPVD1386Hg',
#    'items': {'etag': '41gz9veJn5Rj313UDg3Dg74f7ls',
#              'id': 'UgwDchDlMJtoP-7I-mx4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Watching trailer after 13 years '
#                                         'awesome.... goosebumps'}}}],
#  [{'etag': 'UmXdsXwDzZqBLwR7YZ0HxDjsd6A',
#    'items': {'etag': 'vTmXwCKffEMFlsUujAhOdZZUDXk',
#              'id': 'UgyDps99BnBWDUphB9J4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Nickelodeon saw this and kept '
#                                         'quite??😊'}}},
#   {'etag': 'oNVL0iMDgR73sXUddwxj05XGG18',
#    'items': {'etag': 'j3CqGEFqGDqVflBMgUNasmqJyHA',
#              'id': 'UgxiaRPULwlPZJZdYD14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Dope af'}}},
#   {'etag': 'ubYmECdk2mkNmk-jehlRKNzpCSo',
#    'items': {'etag': 'yFd_8XJnOlH2BEEMtniq3yjXpyc',
#              'id': 'UgyLRK83gkBFhyvlomN4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'faltou a lambida da tropeira na Toph '
#                                         '🥺❤️'}}},
#   {'etag': '-SL-aCDZ8IlkFTwfKJsOEdvKuy8',
#    'items': {'etag': 'd4epJFLiLQ_aewwgi5wU2WrBUrQ',
#              'id': 'UgxbCqnQuQUXSTcZxdF4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I wouldve watched avatar toph vs the '
#                                         'boulder or tournament toph that would '
#                                         'be fun and funny.'}}},
#   {'etag': '-XxMOht8yy0vh_cP8j2x51nUD3Y',
#    'items': {'etag': 'FS6oU6Fwnj3UPJ2G7Yptba1Pch0',
#              'id': 'Ugzz15zHhHW8CnvIpOh4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'The actress who plays Toph is '
#                                         'wonderful. She even really looks like '
#                                         'her. This was a great little origin '
#                                         'story.'}}},
#   {'etag': 'hAjBpStpo7KJlUumdca5x1CSPvE',
#    'items': {'etag': 'MaBZ81sWQEgSbP4Ah0Bnmat12Dw',
#              'id': 'UgwjjiaOzSng_QLl42d4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Lost me with a white girl'}}},
#   {'etag': 'hODySvsWGiVMP8bOg6PdewPPdks',
#    'items': {'etag': 'SYQhxuHvcwPjwxfVo-SxNydVVFM',
#              'id': 'Ugxy2yWPzpH8a99E9414AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Trash 😮'}}},
#   {'etag': 'yYihLbBoyrcncGghWQZs1PjM8IE',
#    'items': {'etag': 'Nz83q_rIQdGLl9Xbdal1qgQxCL0',
#              'id': 'UgzJxGR53RXWF3U5XQp4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I in case the new Netflix life action '
#                                         'right.. This right here is how to do '
#                                         'it right... wow... this is amazing'}}},
#   {'etag': 'Fy4XKhsFes0V3j4LX6Lm5a1J5Jw',
#    'items': {'etag': 'dg2mnFDdldwtFnLi1g_bPFweQbg',
#              'id': 'UgzJDUS4aWCrfk8SHuN4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'this is just amazing. i would love to '
#                                         'see what would you do with a great '
#                                         'budget.\n'
#                                         'nice one 💪'}}},
#   {'etag': 'GywSsq5U0t_1PNnkfwECNYsLO74',
#    'items': {'etag': 'Pvm7tfgDfzCWV5lKfUci5QxDn7E',
#              'id': 'UgwUX9AOD-tyoDCBzZZ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'the protagonist is too ugly'}}},
#   {'etag': 'JOtok7vj40aHSuYaYC5dxIc2_hE',
#    'items': {'etag': 'DCdshR-jA8Sha5Ox6eJQHnZNF_o',
#              'id': 'Ugx-nKHGNXk7w_vZe0V4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'kudos to the actress'}}},
#   {'etag': 's4gCAPbpWkZ3PRFBGj1SmHvNv14',
#    'items': {'etag': 'sIcnsGf1wdpzOY5gPQyrLQshgyM',
#              'id': 'UgwngwJ6MXmNfnrPak94AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'is part of the film her name being '
#                                         'harley queen? thats so close to '
#                                         'harley quinn must be a joke right?'}}},
#   {'etag': 'L2oNtqJ08VEOClctXJ_WuwdEkts',
#    'items': {'etag': 'fvMa2kqQVwdF4Vo8jswgxW7nO74',
#              'id': 'UgxobTHocUAuZHtgz9J4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Much better than the m night movie'}}},
#   {'etag': 'GtXg6H8Lc6eH5d5P-K8XFl1wCfs',
#    'items': {'etag': '1B6GMx1ulV0jlEhoELKd7gc1Ckg',
# ...
#                                         'to be the "white saviour". Almost '
#                                         "like the Na'vi couldn't do it "
#                                         "themselves. I also didn't like how "
#                                         'they accepted him into their tribe, '
#                                         'And made him chief. someone who has '
#                                         'absolutely no ties to the tribe '
#                                         'besides phenotype.  He is one of the '
#                                         'sole reasons for the downfall of '
#                                         'their people. why should they '
#                                         'forgive. The movie to me felt like a '
#                                         'white mans fantasy film to yet again '
#                                         'place themselves at the forefront of '
#                                         'indigenous stories.'}}}],
#  [{'etag': 'DxqWPwMJ4BdtIp9dB01sh1yr1Ik',
#    'items': {'etag': 'ngfzLCsLeiFM3QThsAA5c6GzjEE',
#              'id': 'UgwgTJOoY2Jl5wwFD2R4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "Who'll Lead the Fire Na'vi?🤔\n"
#                                         'https://youtube.com/shorts/o5j95Kxddy4?feature=share3'}}},
#   {'etag': 'mvH_QI9OR9yAEVlyiJUTa4ZEUGA',
#    'items': {'etag': '-9Kl7jsp-5LtyRlMbGgn1LhJb1M',
#              'id': 'UgwByxQ3byfRdC6lG4J4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Makes me wonder if the third movie '
#                                         'will feature an '
#                                         'ash-people-and-sky-people team-up, '
#                                         'everyone for themselves, or if '
#                                         'humanity might even be portrayed '
#                                         'positively.'}}},
#   {'etag': '-AirXu7KqRZFMHQPSSqGUm0L1JI',
#    'items': {'etag': 'R7VBR2TuL9E3RquNvfE7Lw-X9OA',
#              'id': 'UgxY6qoyVEsMX1yw5cR4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Source: trust me bro 😎'}}},
#   {'etag': '-Xzi8f1VODLeK2wokButyVgGfac',
#    'items': {'etag': 'E_r48qKHe8jLO4KaMT3zEi4-C6s',
#              'id': 'UgyNOpD5ZddJiiILF8J4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'What’s next, Air Navi?'}}},
#   {'etag': 'YuwAsfHpvWcDNG5lxUbAcZlhxxI',
#    'items': {'etag': 'gHGeHTmGFrfKNoo9OYu8BFkq_38',
#              'id': 'Ugz1Hzr50-bTx8jB31Z4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "All Na'vi are evil treats."}}},
#   {'etag': 'UeFEvVvKJ-Tk-Eie-9aQ8YSHMmM',
#    'items': {'etag': 'aCm1hCn4WKrbo0x36nUmK85Pja8',
#              'id': 'UgxXF1QSvZx-TkSncgt4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I wanna see general iroh sipping from '
#                                         'his tea 🍵'}}},
#   {'etag': 'adTwZdEqslsnvvlCp3b7BrjJA-Q',
#    'items': {'etag': 'xwGPpedrteDqr0Y5l-S9dgBNuz0',
#              'id': 'UgyOlXbcMR0IT1ptH8p4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Is it just me or are they copying '
#                                         'avatar the last Airbender☠️😭'}}},
#   {'etag': 'Wd-bds43v7cyD8WP5kr4_cgSB9s',
#    'items': {'etag': 'OooJNM0vcdJ0Tb9U-oa-A2clIVg',
#              'id': 'UgzPcu7ng4aMMMKo9W14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Cameron really is ripping off last '
#                                         'air bender'}}},
#   {'etag': 'J_4DkFMHlZoFfPgPkgR6-1CUALk',
#    'items': {'etag': '9Ec9G-TrkVONKEIGCjxBTqWr95k',
#              'id': 'UgwW0ozm4d0t-85mc0h4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': '🙄🙄🙄🤮'}}},
#   {'etag': 'pkS39_GID3ylbpw2cziouKgoO3w',
#    'items': {'etag': 'tdiCqY0qPpdL1CO9UOuCESYtQJQ',
#              'id': 'UgzSK2ixDuqFWPDkey14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Bonus points if the Fire Na’vi teams '
#                                         'up with the RDA.'}}},
#   {'etag': 'McKMauTAqIprq-qwVU1yQ8izb98',
#    'items': {'etag': '0HR94bGMoCS51wkXs-Jdg25U2xg',
#              'id': 'Ugwj-q9NVjvjR9PM0zB4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Imagine the Fire Navi grouping with '
#                                         'the RDA or some shit 😂'}}},
#   {'etag': 'XT5jDHgsW4VdlUCSnQSoNphMUuU',
#    'items': {'etag': 'S2cTs9abTC2NmpZEVJFeeCUEGfw',
#              'id': 'UgwnEltxDN6f9NYu60d4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "Don't worry guys, the good guys will "
#                                         'arrive to save the day again !'}}},
#   {'etag': 'AFs47kApgKsC1OFD7vXV_f5CreQ',
#    'items': {'etag': '-Skrw4A8rV3SzNC9thRdw4KBTIo',
#              'id': 'UgwPZ2CY4SkL6GCP4f14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Im guessing with this esg ratings '
#                                         'system of dieversity inclusion '
#                                         'blablablah im calling it that the '
#                                         'fire navi will be based on white '
#                                         'people 🥱 cos whiteman baahhhhd🐑'}}},
#   {'etag': 'Iwm9hVLPpM0tIf6njknMCdsEydk',
#    'items': {'etag': 'H-6ItvQWL6jFP0OMDy7ir-sU-j0',
#              'id': 'UgyWgHWsGYCC5IG8rpB4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'There is \n'
#                                         "Na'vi\n"
#                                         "Water Na'vi\n"
#                                         "Fire Na'vi \n"
#                                         "What's next? \n"
#                                         "Air Na'vi? \n"
#                                         'And yes I liked my own comment😂'}}},
#   {'etag': 'IZ6QRuuv9uDc2ILIMDvvuG2_1UY',
#    'items': {'etag': 'pjjMX4tBEiVDEuYrIuftzW76Mzk',
#              'id': 'Ugwqxb81n00BDHiOdid4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'i want an actually docomentary from '
#                                         'pandora !!!! all species and all '
#                                         'bioms.......i want see em all'}}},
#   {'etag': 'F_OXapWbE5aOiOJZgvMSY28eCts',
#    'items': {'etag': 'l4Zb1wkALHcgd1nPh00Ts_AWZpE',
#              'id': 'UgzOdmLTghZVxxfmX3p4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'And of course another fight with the '
#                                         'sky people and the colonel'}}},
#   {'etag': '2DfuOWk_kdDwV5-hxexMq1U7AWg',
#    'items': {'etag': 'udNuMzM1X2JQ0uDagFMRi7MoNAY',
#              'id': 'UgxBOsqGQcj2BH5wrtB4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'the navi are already the dark savages '
#                                         'lmao'}}},
#   {'etag': 'dImbOhiuS-uIZhWmyvbAXie1-Ww',
#    'items': {'etag': 'IJlaZIbr0GUEjbPc58NzAvxfIv4',
#              'id': 'UgyIfVkblTRu--QszDN4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Bruh 🤨💅🏻✨'}}},
#   {'etag': '_Bfy9_yrGz6jHRXPrdVEQJwzvRE',
#    'items': {'etag': '9rTNpxRBg2M_G013uLDAMeyFS3o',
#              'id': 'UgxQ15qk8fW2uvGg5m54AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Why is fire always the bad one? Fire '
#                                         'isn’t just bad. Some plants and trees '
#                                         'use it for reproduction, and it '
#                                         'cleans up the forest for more life to '
#                                         'reclaim and grow.'}}},
#   {'etag': 'zxkb44zjy0XpwinaQloftY4ATFI',
#    'items': {'etag': '15zpRsWKncn68fs3cyUTDWTGM4U',
#              'id': 'UgwCJmtgQITb5ArH97N4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'In spanish please? Xd'}}}],
#  [{'etag': 'PYJiZdNrOHpVJIZBJouqk8PmLUI',
#    'items': {'etag': 'oYOyZEGAEzHyMtHBnpr-H0DOTs8',
#              'id': 'UgyzSC9jUUYw_NMKJD94AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'If the live acton is the quite good '
#                                         'at least we getting an animated '
#                                         'avatar movie about their adult life '
#                                         'in  2025 about what happen after the '
#                                         'war and might be based on the '
#                                         'comics.also In  2025 we might get the '
#                                         'new animated series about the earth '
#                                         'bender after korra and in 2026 we get '
#                                         'a movie about zuko life or something '
#                                         'and in later years or months  we get '
#                                         'even more Avatar movies or spin off '
#                                         'series.'}}},
#   {'etag': 'O96xi_pzz6x2zLUPV0Y0x1jcvzo',
#    'items': {'etag': '3Bwn7vnrhWiUKERUFoU-_LKweyo',
#              'id': 'UgyYdOXNZTz8J6ikiD14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'YAAAAAAYYY'}}},
#   {'etag': 'zSOHLY_WyWbPAPeySyI15blsXjU',
#    'items': {'etag': 'k3MtXTTqSinrUCdFpMXFQem0FVA',
#              'id': 'Ugynj-Ahr2-9aJxpTYR4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "NETFLIX DON'T SCREW THIS UP! Please "
#                                         'follow the story and characters '
#                                         "faithfully or we'll have another "
#                                         'Witcher or Cowboy Bebop on our hands '
#                                         '💀. \n'
#                                         '\n'
#                                         'Other than that, the casting looks '
#                                         'great 👍'}}},
#   {'etag': 'nNGAfDvDjwFgQbXryTJmDZmr_vM',
#    'items': {'etag': 'P3RBhrYf_1HkpJWQsRHiqOsztxI',
#              'id': 'Ugy8Gqldgsf6qDbl9It4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'there is no ALTA 2010 movie in ba '
#                                         'sing se'}}},
#   {'etag': 'Vza_93B_sol5hXDOQ6p-QIP0TUI',
#    'items': {'etag': 'ajPGCzYE165SRDPYQca01WAHWHk',
#              'id': 'UgyHRnerB1n0z0RkmCV4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'WHERE ARE BLACK PEOPLE NETFLIX????'}}},
#   {'etag': 'asrnHZcBB8bBeFgyOFe0uzJtG5g',
#    'items': {'etag': '8LN2OQqDiWNjljisOOJjyjId4Zw',
#              'id': 'UgzDUSEpWW5OuEx_YD14AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Such a wasted opportunity to have '
#                                         'Katara\'s actress say "Water, earth, '
#                                         'fire, air" in this teaser like in the '
#                                         'iconic intro.'}}},
#   {'etag': '9HLfqq90XV6HXDRpFsM2B7T1DSw',
#    'items': {'etag': 'QdFuYc8e2cJ3omOothTUDrcnVMw',
#              'id': 'Ugz7ntF1IvY-RbDYCht4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Thank you Netflix'}}},
#   {'etag': 'U4xMANvg7Q_RHODqay_ru3dmp-A',
#    'items': {'etag': '24r7XegNq6SRKlJP5O2jzthU4mM',
#              'id': 'UgwlNTGs7E9_EeDrazN4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Dear God please let this be good'}}},
#   {'etag': 'lE8sqBnFdz9zvcEGqIRiNUKzaQU',
#    'items': {'etag': 'HointXKpe53Jy3XRlDPROv4tFPY',
#              'id': 'UgwgzAg2oOYWMAal34l4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Avatar is peak fiction'}}},
#   {'etag': 'akaIgvS7yD5gojdV_qVPZ2GDG08',
#    'items': {'etag': 'ld6xbX0zIMHhhcL_yQyLeutdYfM',
#              'id': 'UgwEZ9wlinegEWwO6jd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "This is a great start, I can't wait "
#                                         'but pls, fill it with the same level '
#                                         'of humor as the animated series.'}}},
#   {'etag': 'Wyd7seBPYQAzQY6m2vq4efLpOZM',
#    'items': {'etag': 'TcZZlZ6HZc_DCUv_vuA8NyoxAbA',
#              'id': 'Ugz0nrS-5hb9-so-vC94AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'this already better than that razzie '
#                                         'award winning trash we got over '
#                                         'decade ago. and all i saw was the '
#                                         "nation's symbols"}}},
#   {'etag': 'tvTzc1aeq67zi6LnCkCyMvtEdAs',
#    'items': {'etag': 'a54myih8fHi-uGRy8YoT1JuEASM',
#              'id': 'UgwzPqpTbVmjY8uBcOh4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'The animation looks bad!'}}},
#   {'etag': 'x09NeuATbsdzxJ_tWLBQu42LyBI',
#    'items': {'etag': '05x32JDBUCeHXWj0pvEWJa4cEtg',
#              'id': 'UgwG113E0PRRxCneQit4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Every one of us was chronically '
#                                         'traumatized. This better be the cure. '
#                                         '😭'}}},
#   {'etag': 'Oo4-KIooDtywJL3scChFcSNnRbU',
#    'items': {'etag': 'JKeIj985u4DFkBPWhPALTEZn6wM',
#              'id': 'UgxgnDrGyo8l-DUfnP94AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "I'm kinda lookin forward to the "
#                                         'dragon scene'}}},
#   {'etag': 'U90ZjMbvPUdL1JyKjOdG7YOR69s',
#    'items': {'etag': 'g2uEMsjT4YzQYwM30-tozSIsL4g',
#              'id': 'UgwiuKQNI_htHVUuvUZ4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Anything can be better than what '
#                                         'M.Knight tried to throw up all over '
#                                         'the screen.'}}},
#   {'etag': 'Iw1yxLp2bCuXVvtZKSFk1XIFiZY',
#    'items': {'etag': 'aZN-WK_1mDwdrIkai-yIxkRLM-I',
#              'id': 'Ugx2FjWd9j_fatBAOYh4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'Considering how bad the movie was '
#                                         'Netflix has only to do the absolute '
#                                         'bare minimum to be already better.'}}},
#   {'etag': 'DLYGcZiWGV_KNme1ZdGpzsBCG0o',
#    'items': {'etag': 'vfugzzRfnYZtcTtaulMVdAmpNjw',
#              'id': 'UgzDZGih2SKU8hWhTHd4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': "It's going to be good"}}},
#   {'etag': 'kN3jwGDmShauQ6E3EwSMOdVCDxw',
#    'items': {'etag': '7vQi76dpjAW4bMIPq_uLuJeYxPI',
#              'id': 'Ugzb3S7zHxpo1JbPgXt4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'When is the trailer coming out?'}}},
#   {'etag': '5VMQVTJ_AB9yil_vdH7M7tGNDHI',
#    'items': {'etag': 'GHwN2HfiEwvumTgjw-DJe_n37tE',
#              'id': 'UgxvQyJ9rwa6yd-2oyR4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'I want original soundtrack in this.. '
#                                         "else I ain't watching"}}},
#   {'etag': 'lzooRnBF3dIIrmMHBhruuYpf7vU',
#    'items': {'etag': 'XZULA4UQ31igYcznulEhQLLaTf0',
#              'id': 'UgwhFG8U-GQVDyJ8VlN4AaABAg',
#              'kind': 'youtube#comment',
#              'snippet': {'textDisplay': 'They had done it for One Piece, '
#                                         'pleeeease do it for ATLA! 🥹'}}}]]

# %% [markdown]
# > 3.c Write a program to export the output of question 3.b in JSON file format and submit the file as part of the assignment (3 marks)

# %%
def export_to_json(comments_list, file_path):
    with open(file_path, 'w') as json_file:
        json.dump(comments_list, json_file, indent=2)
    
file_path = 'comments.json'
export_to_json(comments_list, file_path)

# %% [markdown]
# >3.d Write a function to get  the likes vs views ratio of the top 10 videos obtained in 3.a with the highest comments (3 marks)

# %%
def get_ratio(file_name):
    df = sorted_data(file_name)
    
    df['no_of_likes']= df.no_of_likes.astype(int)
    df['no_of_views']= df.no_of_views.astype(int)
    
    df = df.loc[:, ["no_of_likes", "no_of_views"]].head(10)
    df['ratio']=df['no_of_likes']/df["no_of_views"]
    
    return df


print(get_ratio("./data.csv"))
# Out:
#     no_of_likes  no_of_views     ratio
# 2       1042788     58124167  0.017941
# 0        341150     13801173  0.024719
# 9        682437     27758248  0.024585
# 42       154759      5118065  0.030238
# 4         81210     12790571  0.006349
# 41       135054      2217164  0.060913
# 35       187370      2270073  0.082539
# 34        25924       430566  0.060209
# 25       350315      7719047  0.045383
# 31        55194      3256245  0.016950
